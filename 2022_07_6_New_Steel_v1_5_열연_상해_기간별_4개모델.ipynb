# %% [markdown]
# <a href="https://colab.research.google.com/github/freejae98/freejae98.github.io/blob/master/2022_07_6_New_Steel_v1_5_%EC%97%B4%EC%97%B0_%EC%83%81%ED%95%B4_%EA%B8%B0%EA%B0%84%EB%B3%84_4%EA%B0%9C%EB%AA%A8%EB%8D%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ignore the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# System related and data input controls
import os

# Data manipulation, visualization and useful functions
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
pd.options.display.max_rows = 50
pd.options.display.max_columns = 40
import numpy as np
from itertools import product # iterative combinations
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

# Modeling algorithms
# General(Statistics/Econometrics)
from sklearn import preprocessing
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats

# Regression
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.kernel_ridge import KernelRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor, GradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# Classification
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# Model selection
from sklearn.model_selection import train_test_split,cross_validate
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

# Evaluation metrics
# for regression
from sklearn.metrics import mean_squared_log_error, mean_squared_error,  r2_score, mean_absolute_error
# for classification
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
### Evaluation of 1 pair of set
def evaluation(Y_real, Y_pred, graph_on=False):
    loss_length = len(Y_real.values.flatten()) - len(Y_pred)
    if loss_length != 0:
        Y_real = Y_real[loss_length:]
    if graph_on == True:
        pd.concat([Y_real, pd.DataFrame(Y_pred, index=Y_real.index, columns=['prediction'])], axis=1).plot(kind='line', figsize=(20,6),
                                                                                                           xlim=(Y_real.index.min(),Y_real.index.max()),
                                                                                                           linewidth=3, fontsize=20)
        plt.title('Time Series of Target', fontsize=20)
        plt.xlabel('Index', fontsize=15)
        plt.ylabel('Target Value', fontsize=15)
    MAE = abs(Y_real.values.flatten() - Y_pred).mean()
    MSE = ((Y_real.values.flatten() - Y_pred)**2).mean()
    MAPE = (abs(Y_real.values.flatten() - Y_pred)/Y_real.values.flatten()*100).mean()
    Score = pd.DataFrame([MAE, MSE, MAPE], index=['MAE', 'MSE', 'MAPE'], columns=['Score']).T
    Residual = pd.DataFrame(Y_real.values.flatten() - Y_pred, index=Y_real.index, columns=['Error'])
    return Score, Residual
# Score_tr, Residual_tr = evaluation(Y_train, pred_tr_reg1, graph_on=True)


### Evaluation of train/test pairs
def evaluation_trte(Y_real_tr, Y_pred_tr, Y_real_te, Y_pred_te, graph_on=False):
    Score_tr, Residual_tr = evaluation(Y_real_tr, Y_pred_tr, graph_on=graph_on)
    Score_te, Residual_te = evaluation(Y_real_te, Y_pred_te, graph_on=graph_on)
    Score_trte = pd.concat([Score_tr, Score_te], axis=0)
    Score_trte.index = ['Train', 'Test']
    return Score_trte, Residual_tr, Residual_te
# Score_reg1, Resid_tr_reg1, Resid_te_reg1 = evaluation_trte(Y_train, pred_tr_reg1, Y_test, pred_te_reg1, graph_on=True)

# %%
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, Activation, Flatten, Dropout
from keras.layers import SimpleRNN, LSTM, GRU

from pickle import dump

# %%
# Data Loading
df = pd.read_excel('/content/data_completed.xlsx')   #dataset_6 사용
df.set_index('Date', inplace=True)

X_colname = ['MA5']
raw_all = df[X_colname]

# raw_all = df.loc[df['MA5'] != np.nan, :]

#20%는 테스트용 구분함
# PCT = 0.2
# c_num = int(len(raw_all.index) * (1- PCT))

# criteria = raw_all.index[int(c_num)]


# raw_all = df.loc[df.index >= '2019-12-30', X_colname]

# Parameters - 시작점을 달리할 경우 정확도에 어떤 영향을 얻을 수 있는지?

start_point = '2017-1-1'     #기존 시작점 : '2019-12-30'
# start_list = ['2016-1-1', '2018-1-1', '2020-1-1', '2021-1-1']     #기존 시작점 : '2019-12-30'
criteria = '2022-04-01'     #기존 시작점 : '2021-09-01'

scaler = preprocessing.MinMaxScaler()
sequence = 15   # → optimization 진행
batch_size = 16
epoch = 300
verbose = 1  # 원래는 1
dropout_ratio = 0

#며칠이나 이후 것을 예상할 것인지 (20 = 4주 후)
predict_day = 5    #5*1 # 1주 후

predict_day_list = [5, 10, 15, 20]    #각 1,2,3,4주 후



# Feature Engineering
## Train & Test Split
# train = raw_all.loc[raw_all.index < criteria,:]

# %%
#################################################################################
#
# ----- Feature 1, GRU 버전 -------
#
#################################################################################

from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor = 'val_loss', min_delta = 0, patience = 50, mode = 'min')


####################### iterations #######################
Score = dict()

temp = 0

# batchsize_list = [i for i in range(5, 11, 5)]
for i in tqdm(predict_day_list):
    # sequence = i
    # start_point = i

    predict_day = i   #예측일 변경

    temp = temp + 1


    train = raw_all.loc[(raw_all.index >= start_point) & (raw_all.index < criteria)]

    test = raw_all.loc[raw_all.index >= criteria,:]
    print('Train_size:', train.shape, 'Test_size:', test.shape)

    print('Train_start:', train.index[0])
    print('Test_start:', test.index[0])

    # Scaling
    train_scaled = scaler.fit_transform(train)
    test_scaled = scaler.transform(test)



    ## X / Y Split
    X_train, Y_train = [], []
    for index in range(0, len(train_scaled) - sequence - predict_day):
        X_train.append(train_scaled[index: index + sequence])
        Y_train.append(train_scaled[index + sequence + predict_day])
    X_test, Y_test = [], []
    for index in range(0, len(test_scaled) - sequence - predict_day):
        X_test.append(test_scaled[index: index + sequence])
        Y_test.append(test_scaled[index + sequence + predict_day])

    ## Retype and Reshape
    X_train, Y_train = np.array(X_train), np.array(Y_train)
    X_test, Y_test = np.array(X_test), np.array(Y_test)
    print('X_train:', X_train.shape, 'Y_train:', Y_train.shape)
    print('X_test:', X_test.shape, 'Y_test:', Y_test.shape)

    # GRU
    model = Sequential()
    model.add(GRU(128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True, activation='relu'))
    model.add(Dropout(dropout_ratio)) 
    model.add(GRU(256, return_sequences=True, activation="relu"))
    model.add(Dropout(dropout_ratio)) 
    model.add(GRU(128, return_sequences=True, activation="relu"))
    model.add(Dropout(dropout_ratio)) 
    model.add(GRU(64, return_sequences=False, activation="relu"))
    model.add(Dropout(dropout_ratio)) 
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    # model.summary()
    model_fit = model.fit(X_train, Y_train, 
                          batch_size=batch_size, epochs=epoch,
                          verbose=verbose, validation_data=(X_test, Y_test), callbacks = [early_stopping])

    plt.plot(pd.DataFrame(model_fit.history))
    plt.grid(True)
    plt.show()

    # prediction
    Y_train_pred = model.predict(X_train)
    Y_test_pred = model.predict(X_test)

    # evaluation
    result = model.evaluate(X_test, Y_test_pred)
    if scaler != []:
        Y_train = scaler.inverse_transform(Y_train)
        Y_train_pred = scaler.inverse_transform(Y_train_pred)
        Y_test = scaler.inverse_transform(Y_test)
        Y_test_pred = scaler.inverse_transform(Y_test_pred)
    Score_GRU, Residual_tr, Residual_te = evaluation_trte(pd.DataFrame(Y_train), Y_train_pred.flatten(), 
                                                          pd.DataFrame(Y_test), Y_test_pred.flatten(), graph_on=True)
    display(Score_GRU)
# if simul_test == 1:
    Score[str(predict_day)] = Score_GRU



    #모델, scaler 저장하기
    model.save("steel_" + str(temp) + "d.h5")

    dump(scaler, open("scaler_" + str(temp) + "d.pkl", 'wb'))



# error analysis
# error_analysis(Residual_te, ['Error'], pd.DataFrame(X_train.reshape(X_train.shape[0], X_train.shape[1])), graph_on=True)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Train_size: (1369, 1) Test_size: (45, 1)
# Train_start: 2017-01-02 00:00:00
# Test_start: 2022-04-01 00:00:00
# X_train: (1349, 15, 1) Y_train: (1349, 1)
# X_test: (25, 15, 1) Y_test: (25, 1)
# Epoch 1/300
# 85/85 [==============================] - 13s 88ms/step - loss: 0.0133 - val_loss: 0.0041
# Epoch 2/300
# 85/85 [==============================] - 7s 85ms/step - loss: 0.0020 - val_loss: 0.0045
# Epoch 3/300
# 85/85 [==============================] - 7s 83ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 4/300
# 85/85 [==============================] - 7s 85ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 5/300
# 85/85 [==============================] - 8s 88ms/step - loss: 0.0019 - val_loss: 0.0066
# Epoch 6/300
# 85/85 [==============================] - 7s 81ms/step - loss: 0.0017 - val_loss: 0.0038
# Epoch 7/300
# 85/85 [==============================] - 7s 80ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 8/300
# 85/85 [==============================] - 7s 81ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 9/300
# 85/85 [==============================] - 8s 100ms/step - loss: 0.0014 - val_loss: 0.0060
# Epoch 10/300
# 85/85 [==============================] - 7s 84ms/step - loss: 0.0014 - val_loss: 0.0070
# Epoch 11/300
# 85/85 [==============================] - 7s 80ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 12/300
# 85/85 [==============================] - 7s 80ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 13/300
# 85/85 [==============================] - 7s 80ms/step - loss: 0.0012 - val_loss: 0.0040
# Epoch 14/300
# 85/85 [==============================] - 7s 80ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 15/300
# 85/85 [==============================] - 7s 80ms/step - loss: 0.0012 - val_loss: 0.0050
# Epoch 16/300
# 85/85 [==============================] - 7s 80ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 17/300
# 85/85 [==============================] - 7s 81ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 18/300
# 85/85 [==============================] - 7s 80ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 19/300
# 85/85 [==============================] - 7s 80ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 20/300
# 85/85 [==============================] - 7s 80ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 21/300
# 85/85 [==============================] - 7s 81ms/step - loss: 0.0011 - val_loss: 8.9522e-04
# Epoch 22/300
# 85/85 [==============================] - 7s 82ms/step - loss: 0.0012 - val_loss: 0.0105
# Epoch 23/300
# 85/85 [==============================] - 7s 81ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 24/300
# 85/85 [==============================] - 7s 81ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 25/300
# 85/85 [==============================] - 7s 82ms/step - loss: 0.0012 - val_loss: 0.0028
# Epoch 26/300
# 85/85 [==============================] - 7s 82ms/step - loss: 9.7079e-04 - val_loss: 0.0028
# Epoch 27/300
# 85/85 [==============================] - 7s 81ms/step - loss: 9.2162e-04 - val_loss: 0.0043
# Epoch 28/300
# 85/85 [==============================] - 7s 79ms/step - loss: 9.9922e-04 - val_loss: 0.0016
# Epoch 29/300
# 85/85 [==============================] - 7s 82ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 30/300
# 85/85 [==============================] - 7s 83ms/step - loss: 9.4234e-04 - val_loss: 0.0018
# Epoch 31/300
# 85/85 [==============================] - 7s 81ms/step - loss: 9.5305e-04 - val_loss: 0.0020
# Epoch 32/300
# 85/85 [==============================] - 7s 81ms/step - loss: 8.8630e-04 - val_loss: 0.0034
# Epoch 33/300
# 85/85 [==============================] - 7s 83ms/step - loss: 9.6132e-04 - val_loss: 0.0030
# Epoch 34/300
# 85/85 [==============================] - 7s 80ms/step - loss: 9.1181e-04 - val_loss: 0.0014
# Epoch 35/300
# 85/85 [==============================] - 7s 82ms/step - loss: 9.0879e-04 - val_loss: 0.0022
# Epoch 36/300
# 85/85 [==============================] - 7s 80ms/step - loss: 8.3913e-04 - val_loss: 0.0022
# Epoch 37/300
# 85/85 [==============================] - 7s 79ms/step - loss: 8.5087e-04 - val_loss: 8.4483e-04
# Epoch 38/300
# 85/85 [==============================] - 7s 79ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 39/300
# 85/85 [==============================] - 7s 78ms/step - loss: 8.5070e-04 - val_loss: 0.0029
# Epoch 40/300
# 85/85 [==============================] - 7s 80ms/step - loss: 9.9554e-04 - val_loss: 0.0047
# Epoch 41/300
# 85/85 [==============================] - 7s 79ms/step - loss: 9.5719e-04 - val_loss: 0.0019
# Epoch 42/300
# 85/85 [==============================] - 7s 80ms/step - loss: 8.9583e-04 - val_loss: 8.8576e-04
# Epoch 43/300
# 85/85 [==============================] - 7s 80ms/step - loss: 8.5389e-04 - val_loss: 0.0011
# Epoch 44/300
# 85/85 [==============================] - 7s 81ms/step - loss: 8.4526e-04 - val_loss: 0.0038
# Epoch 45/300
# 85/85 [==============================] - 7s 79ms/step - loss: 8.8408e-04 - val_loss: 0.0014
# Epoch 46/300
# 85/85 [==============================] - 7s 80ms/step - loss: 9.5116e-04 - val_loss: 0.0017
# Epoch 47/300
# 85/85 [==============================] - 7s 82ms/step - loss: 9.0640e-04 - val_loss: 0.0021
# Epoch 48/300
# 85/85 [==============================] - 7s 83ms/step - loss: 8.0429e-04 - val_loss: 0.0020
# Epoch 49/300
# 85/85 [==============================] - 7s 82ms/step - loss: 8.8482e-04 - val_loss: 0.0014
# Epoch 50/300
# 85/85 [==============================] - 7s 82ms/step - loss: 7.7650e-04 - val_loss: 0.0021
# Epoch 51/300
# 85/85 [==============================] - 7s 82ms/step - loss: 8.8993e-04 - val_loss: 9.2108e-04
# Epoch 52/300
# 85/85 [==============================] - 7s 82ms/step - loss: 8.2793e-04 - val_loss: 0.0013
# Epoch 53/300
# 85/85 [==============================] - 7s 80ms/step - loss: 8.5532e-04 - val_loss: 0.0025
# Epoch 54/300
# 85/85 [==============================] - 7s 81ms/step - loss: 9.0991e-04 - val_loss: 0.0018
# Epoch 55/300
# 85/85 [==============================] - 7s 80ms/step - loss: 8.4986e-04 - val_loss: 0.0024
# Epoch 56/300
# 85/85 [==============================] - 8s 95ms/step - loss: 8.1954e-04 - val_loss: 0.0023
# Epoch 57/300
# 85/85 [==============================] - 7s 81ms/step - loss: 8.6546e-04 - val_loss: 0.0016
# Epoch 58/300
# 85/85 [==============================] - 7s 81ms/step - loss: 8.5552e-04 - val_loss: 0.0013
# Epoch 59/300
# 85/85 [==============================] - 7s 80ms/step - loss: 8.8599e-04 - val_loss: 0.0033
# Epoch 60/300
# 85/85 [==============================] - 7s 80ms/step - loss: 8.3248e-04 - val_loss: 0.0029
# Epoch 61/300
# 85/85 [==============================] - 7s 83ms/step - loss: 8.9941e-04 - val_loss: 0.0010
# Epoch 62/300
# 85/85 [==============================] - 7s 79ms/step - loss: 8.8436e-04 - val_loss: 9.9769e-04
# Epoch 63/300
# 85/85 [==============================] - 7s 81ms/step - loss: 8.4898e-04 - val_loss: 0.0018
# Epoch 64/300
# 85/85 [==============================] - 7s 80ms/step - loss: 7.8785e-04 - val_loss: 0.0026
# Epoch 65/300
# 85/85 [==============================] - 7s 81ms/step - loss: 9.4797e-04 - val_loss: 0.0019
# Epoch 66/300
# 85/85 [==============================] - 7s 80ms/step - loss: 8.0915e-04 - val_loss: 0.0029
# Epoch 67/300
# 85/85 [==============================] - 7s 81ms/step - loss: 9.3484e-04 - val_loss: 0.0011
# Epoch 68/300
# 85/85 [==============================] - 7s 80ms/step - loss: 9.3548e-04 - val_loss: 0.0017
# Epoch 69/300
# 85/85 [==============================] - 7s 80ms/step - loss: 7.7192e-04 - val_loss: 0.0016
# Epoch 70/300
# 85/85 [==============================] - 7s 79ms/step - loss: 8.8126e-04 - val_loss: 8.3902e-04
# Epoch 71/300
# 85/85 [==============================] - 7s 79ms/step - loss: 7.8283e-04 - val_loss: 9.0139e-04
# Epoch 72/300
# 85/85 [==============================] - 7s 82ms/step - loss: 9.6059e-04 - val_loss: 0.0016
# Epoch 73/300
# 85/85 [==============================] - 7s 84ms/step - loss: 8.5465e-04 - val_loss: 0.0016
# Epoch 74/300
# 85/85 [==============================] - 7s 82ms/step - loss: 8.1965e-04 - val_loss: 0.0017
# Epoch 75/300
# 85/85 [==============================] - 7s 84ms/step - loss: 7.5880e-04 - val_loss: 0.0018
# Epoch 76/300
# 85/85 [==============================] - 7s 80ms/step - loss: 7.8852e-04 - val_loss: 9.5705e-04
# Epoch 77/300
# 85/85 [==============================] - 7s 81ms/step - loss: 7.6569e-04 - val_loss: 0.0021
# Epoch 78/300
# 85/85 [==============================] - 7s 80ms/step - loss: 7.6503e-04 - val_loss: 9.3278e-04
# Epoch 79/300
# 85/85 [==============================] - 7s 81ms/step - loss: 8.1591e-04 - val_loss: 0.0041
# Epoch 80/300
# 85/85 [==============================] - 7s 81ms/step - loss: 8.5080e-04 - val_loss: 0.0018
# Epoch 81/300
# 85/85 [==============================] - 7s 82ms/step - loss: 8.1690e-04 - val_loss: 0.0011
# Epoch 82/300
# 85/85 [==============================] - 7s 81ms/step - loss: 9.1658e-04 - val_loss: 0.0011
# Epoch 83/300
# 85/85 [==============================] - 7s 81ms/step - loss: 7.8866e-04 - val_loss: 0.0031
# Epoch 84/300
# 85/85 [==============================] - 7s 81ms/step - loss: 8.6500e-04 - val_loss: 0.0012
# Epoch 85/300
# 85/85 [==============================] - 7s 81ms/step - loss: 7.8853e-04 - val_loss: 0.0024
# Epoch 86/300
# 85/85 [==============================] - 7s 79ms/step - loss: 7.7989e-04 - val_loss: 0.0014
# Epoch 87/300
# 85/85 [==============================] - 7s 81ms/step - loss: 8.1925e-04 - val_loss: 0.0023
# Epoch 88/300
# 85/85 [==============================] - 7s 80ms/step - loss: 7.5880e-04 - val_loss: 0.0035
# Epoch 89/300
# 85/85 [==============================] - 7s 83ms/step - loss: 8.0154e-04 - val_loss: 0.0019
# Epoch 90/300
# 85/85 [==============================] - 7s 83ms/step - loss: 8.2579e-04 - val_loss: 0.0031
# Epoch 91/300
# 85/85 [==============================] - 7s 81ms/step - loss: 8.4777e-04 - val_loss: 0.0016
# Epoch 92/300
# 85/85 [==============================] - 7s 81ms/step - loss: 7.3883e-04 - val_loss: 0.0015
# Epoch 93/300
# 85/85 [==============================] - 7s 83ms/step - loss: 8.3081e-04 - val_loss: 0.0028
# Epoch 94/300
# 85/85 [==============================] - 7s 81ms/step - loss: 7.4948e-04 - val_loss: 0.0015
# Epoch 95/300
# 85/85 [==============================] - 7s 80ms/step - loss: 7.5732e-04 - val_loss: 0.0021
# Epoch 96/300
# 85/85 [==============================] - 7s 81ms/step - loss: 7.4677e-04 - val_loss: 0.0019
# Epoch 97/300
# 85/85 [==============================] - 7s 79ms/step - loss: 7.5029e-04 - val_loss: 8.6951e-04
# Epoch 98/300
# 85/85 [==============================] - 7s 80ms/step - loss: 8.2951e-04 - val_loss: 0.0013
# Epoch 99/300
# 85/85 [==============================] - 7s 81ms/step - loss: 8.3434e-04 - val_loss: 0.0044
# Epoch 100/300
# 85/85 [==============================] - 7s 79ms/step - loss: 7.5803e-04 - val_loss: 0.0016
# Epoch 101/300
# 85/85 [==============================] - 7s 81ms/step - loss: 7.4283e-04 - val_loss: 0.0016
# Epoch 102/300
# 85/85 [==============================] - 7s 80ms/step - loss: 7.4283e-04 - val_loss: 0.0011
# Epoch 103/300
# 85/85 [==============================] - 7s 81ms/step - loss: 7.5877e-04 - val_loss: 0.0036
# Epoch 104/300
# 85/85 [==============================] - 7s 80ms/step - loss: 8.7786e-04 - val_loss: 9.6889e-04
# Epoch 105/300
# 85/85 [==============================] - 7s 79ms/step - loss: 7.8580e-04 - val_loss: 0.0010
# Epoch 106/300
# 85/85 [==============================] - 7s 81ms/step - loss: 7.6495e-04 - val_loss: 0.0016
# Epoch 107/300
# 85/85 [==============================] - 7s 80ms/step - loss: 7.4085e-04 - val_loss: 0.0012
# Epoch 108/300
# 85/85 [==============================] - 7s 80ms/step - loss: 7.7540e-04 - val_loss: 0.0019
# Epoch 109/300
# 85/85 [==============================] - 7s 80ms/step - loss: 7.6121e-04 - val_loss: 0.0025
# Epoch 110/300
# 85/85 [==============================] - 7s 81ms/step - loss: 7.5956e-04 - val_loss: 0.0022
# Epoch 111/300
# 85/85 [==============================] - 7s 79ms/step - loss: 8.1518e-04 - val_loss: 0.0011
# Epoch 112/300
# 85/85 [==============================] - 7s 81ms/step - loss: 7.2132e-04 - val_loss: 0.0016
# Epoch 113/300
# 85/85 [==============================] - 7s 79ms/step - loss: 7.8312e-04 - val_loss: 0.0029
# Epoch 114/300
# 85/85 [==============================] - 7s 80ms/step - loss: 7.0968e-04 - val_loss: 0.0017
# Epoch 115/300
# 85/85 [==============================] - 7s 80ms/step - loss: 7.7956e-04 - val_loss: 0.0017
# Epoch 116/300
# 85/85 [==============================] - 7s 81ms/step - loss: 7.8443e-04 - val_loss: 0.0019
# Epoch 117/300
# 85/85 [==============================] - 7s 82ms/step - loss: 7.5151e-04 - val_loss: 8.6204e-04
# Epoch 118/300
# 85/85 [==============================] - 7s 82ms/step - loss: 7.2438e-04 - val_loss: 8.7235e-04
# Epoch 119/300
# 85/85 [==============================] - 7s 83ms/step - loss: 7.2832e-04 - val_loss: 0.0022
# Epoch 120/300
# 85/85 [==============================] - 7s 84ms/step - loss: 7.7128e-04 - val_loss: 0.0020
# 1/1 [==============================] - 0s 41ms/step - loss: 6.7502e-16
#         MAE    MSE  MAPE
# Train 10.51 226.34  1.61
# Test  19.63 681.66  2.66
#  25%|██▌       | 1/4 [14:31<43:33, 871.11s/it]
# Train_size: (1369, 1) Test_size: (45, 1)
# Train_start: 2017-01-02 00:00:00
# Test_start: 2022-04-01 00:00:00
# X_train: (1344, 15, 1) Y_train: (1344, 1)
# X_test: (20, 15, 1) Y_test: (20, 1)
# Epoch 1/300
# 84/84 [==============================] - 10s 80ms/step - loss: 0.0181 - val_loss: 0.0106
# Epoch 2/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0032 - val_loss: 0.0255
# Epoch 3/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0031 - val_loss: 0.0128
# Epoch 4/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0030 - val_loss: 0.0140
# Epoch 5/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0029 - val_loss: 0.0089
# Epoch 6/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0027 - val_loss: 0.0191
# Epoch 7/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0027 - val_loss: 0.0096
# Epoch 8/300
# 84/84 [==============================] - 7s 87ms/step - loss: 0.0025 - val_loss: 0.0089
# Epoch 9/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0028 - val_loss: 0.0048
# Epoch 10/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0025 - val_loss: 0.0053
# Epoch 11/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0024 - val_loss: 0.0106
# Epoch 12/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 13/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0025 - val_loss: 0.0037
# Epoch 14/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0023 - val_loss: 0.0240
# Epoch 15/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0024 - val_loss: 0.0068
# Epoch 16/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0023 - val_loss: 0.0072
# Epoch 17/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0023 - val_loss: 0.0101
# Epoch 18/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0022 - val_loss: 0.0081
# Epoch 19/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0021 - val_loss: 0.0066
# Epoch 20/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0024 - val_loss: 0.0086
# Epoch 21/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0020 - val_loss: 0.0085
# Epoch 22/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0020 - val_loss: 0.0041
# Epoch 23/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0020 - val_loss: 0.0071
# Epoch 24/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0019 - val_loss: 0.0097
# Epoch 25/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 26/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0019 - val_loss: 0.0057
# Epoch 27/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0019 - val_loss: 0.0047
# Epoch 28/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0019 - val_loss: 0.0129
# Epoch 29/300
# 84/84 [==============================] - 6s 71ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 30/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0021 - val_loss: 0.0075
# Epoch 31/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0021 - val_loss: 0.0050
# Epoch 32/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0019 - val_loss: 0.0123
# Epoch 33/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0018 - val_loss: 0.0044
# Epoch 34/300
# 84/84 [==============================] - 6s 71ms/step - loss: 0.0020 - val_loss: 0.0072
# Epoch 35/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0020 - val_loss: 0.0035
# Epoch 36/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0019 - val_loss: 0.0058
# Epoch 37/300
# 84/84 [==============================] - 6s 71ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 38/300
# 84/84 [==============================] - 7s 86ms/step - loss: 0.0018 - val_loss: 0.0060
# Epoch 39/300
# 84/84 [==============================] - 6s 76ms/step - loss: 0.0018 - val_loss: 0.0065
# Epoch 40/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0019 - val_loss: 0.0038
# Epoch 41/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0017 - val_loss: 0.0103
# Epoch 42/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0018 - val_loss: 0.0078
# Epoch 43/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0021 - val_loss: 0.0073
# Epoch 44/300
# 84/84 [==============================] - 6s 75ms/step - loss: 0.0018 - val_loss: 0.0076
# Epoch 45/300
# 84/84 [==============================] - 6s 75ms/step - loss: 0.0018 - val_loss: 0.0099
# Epoch 46/300
# 84/84 [==============================] - 6s 77ms/step - loss: 0.0018 - val_loss: 0.0079
# Epoch 47/300
# 84/84 [==============================] - 6s 75ms/step - loss: 0.0018 - val_loss: 0.0052
# Epoch 48/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0019 - val_loss: 0.0056
# Epoch 49/300
# 84/84 [==============================] - 6s 75ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 50/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0019 - val_loss: 0.0073
# Epoch 51/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0017 - val_loss: 0.0112
# Epoch 52/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 53/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0018 - val_loss: 0.0070
# Epoch 54/300
# 84/84 [==============================] - 6s 75ms/step - loss: 0.0018 - val_loss: 0.0073
# Epoch 55/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0017 - val_loss: 0.0052
# Epoch 56/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0018 - val_loss: 0.0070
# Epoch 57/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0018 - val_loss: 0.0070
# Epoch 58/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0018 - val_loss: 0.0085
# Epoch 59/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0019 - val_loss: 0.0055
# Epoch 60/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0018 - val_loss: 0.0076
# Epoch 61/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 62/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0017 - val_loss: 0.0071
# Epoch 63/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0018 - val_loss: 0.0051
# Epoch 64/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0019 - val_loss: 0.0067
# Epoch 65/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0018 - val_loss: 0.0040
# Epoch 66/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0017 - val_loss: 0.0053
# Epoch 67/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0018 - val_loss: 0.0041
# Epoch 68/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0017 - val_loss: 0.0045
# Epoch 69/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 70/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0018 - val_loss: 0.0072
# Epoch 71/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0017 - val_loss: 0.0045
# Epoch 72/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0019 - val_loss: 0.0078
# Epoch 73/300
# 84/84 [==============================] - 6s 75ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 74/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 75/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0017 - val_loss: 0.0099
# Epoch 76/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0017 - val_loss: 0.0051
# Epoch 77/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0017 - val_loss: 0.0080
# Epoch 78/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0017 - val_loss: 0.0062
# Epoch 79/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0016 - val_loss: 0.0061
# Epoch 80/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 81/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0017 - val_loss: 0.0049
# Epoch 82/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0017 - val_loss: 0.0069
# Epoch 83/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0019 - val_loss: 0.0097
# Epoch 84/300
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0017 - val_loss: 0.0046
# Epoch 85/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0017 - val_loss: 0.0071
# Epoch 86/300
# 84/84 [==============================] - 6s 75ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 87/300
# 84/84 [==============================] - 6s 75ms/step - loss: 0.0017 - val_loss: 0.0047
# 1/1 [==============================] - 0s 37ms/step - loss: 7.1054e-16
#         MAE      MSE  MAPE
# Train 17.98   580.13  2.79
# Test  34.10 1,607.84  4.66
#  50%|█████     | 2/4 [23:59<23:06, 693.25s/it]
# Train_size: (1369, 1) Test_size: (45, 1)
# Train_start: 2017-01-02 00:00:00
# Test_start: 2022-04-01 00:00:00
# X_train: (1339, 15, 1) Y_train: (1339, 1)
# X_test: (15, 15, 1) Y_test: (15, 1)
# Epoch 1/300
# 84/84 [==============================] - 14s 91ms/step - loss: 0.0183 - val_loss: 0.0055
# Epoch 2/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0049 - val_loss: 0.0411
# Epoch 3/300
# 84/84 [==============================] - 8s 97ms/step - loss: 0.0046 - val_loss: 0.0179
# Epoch 4/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0041 - val_loss: 0.0184
# Epoch 5/300
# 84/84 [==============================] - 7s 80ms/step - loss: 0.0042 - val_loss: 0.0113
# Epoch 6/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0039 - val_loss: 0.0115
# Epoch 7/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0037 - val_loss: 0.0148
# Epoch 8/300
# 84/84 [==============================] - 7s 80ms/step - loss: 0.0034 - val_loss: 0.0119
# Epoch 9/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0035 - val_loss: 0.0179
# Epoch 10/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0036 - val_loss: 0.0460
# Epoch 11/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0038 - val_loss: 0.0251
# Epoch 12/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0033 - val_loss: 0.0296
# Epoch 13/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0038 - val_loss: 0.0132
# Epoch 14/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0035 - val_loss: 0.0149
# Epoch 15/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0032 - val_loss: 0.0100
# Epoch 16/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0033 - val_loss: 0.0165
# Epoch 17/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0033 - val_loss: 0.0161
# Epoch 18/300
# 84/84 [==============================] - 7s 80ms/step - loss: 0.0031 - val_loss: 0.0120
# Epoch 19/300
# 84/84 [==============================] - 7s 80ms/step - loss: 0.0032 - val_loss: 0.0216
# Epoch 20/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0030 - val_loss: 0.0139
# Epoch 21/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0029 - val_loss: 0.0087
# Epoch 22/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0029 - val_loss: 0.0069
# Epoch 23/300
# 84/84 [==============================] - 7s 80ms/step - loss: 0.0031 - val_loss: 0.0135
# Epoch 24/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0029 - val_loss: 0.0119
# Epoch 25/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0028 - val_loss: 0.0112
# Epoch 26/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0028 - val_loss: 0.0089
# Epoch 27/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0031 - val_loss: 0.0115
# Epoch 28/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0029 - val_loss: 0.0105
# Epoch 29/300
# 84/84 [==============================] - 7s 84ms/step - loss: 0.0028 - val_loss: 0.0259
# Epoch 30/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0030 - val_loss: 0.0105
# Epoch 31/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0028 - val_loss: 0.0067
# Epoch 32/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0029 - val_loss: 0.0159
# Epoch 33/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0027 - val_loss: 0.0095
# Epoch 34/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0029 - val_loss: 0.0122
# Epoch 35/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0029 - val_loss: 0.0138
# Epoch 36/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0027 - val_loss: 0.0086
# Epoch 37/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0028 - val_loss: 0.0103
# Epoch 38/300
# 84/84 [==============================] - 7s 86ms/step - loss: 0.0028 - val_loss: 0.0063
# Epoch 39/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0028 - val_loss: 0.0075
# Epoch 40/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0027 - val_loss: 0.0154
# Epoch 41/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0027 - val_loss: 0.0116
# Epoch 42/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0028 - val_loss: 0.0098
# Epoch 43/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0028 - val_loss: 0.0108
# Epoch 44/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0028 - val_loss: 0.0133
# Epoch 45/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0027 - val_loss: 0.0075
# Epoch 46/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0029 - val_loss: 0.0166
# Epoch 47/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0027 - val_loss: 0.0074
# Epoch 48/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0025 - val_loss: 0.0108
# Epoch 49/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0025 - val_loss: 0.0084
# Epoch 50/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0026 - val_loss: 0.0142
# Epoch 51/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0029 - val_loss: 0.0160
# 1/1 [==============================] - 0s 36ms/step - loss: 7.1054e-16
#         MAE      MSE  MAPE
# Train 21.19   824.66  3.31
# Test  68.56 5,493.00  9.51
#  75%|███████▌  | 3/4 [30:00<09:01, 541.40s/it]
# Train_size: (1369, 1) Test_size: (45, 1)
# Train_start: 2017-01-02 00:00:00
# Test_start: 2022-04-01 00:00:00
# X_train: (1334, 15, 1) Y_train: (1334, 1)
# X_test: (10, 15, 1) Y_test: (10, 1)
# Epoch 1/300
# 84/84 [==============================] - 13s 89ms/step - loss: 0.0199 - val_loss: 0.0324
# Epoch 2/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0060 - val_loss: 0.0146
# Epoch 3/300
# 84/84 [==============================] - 7s 85ms/step - loss: 0.0063 - val_loss: 0.0122
# Epoch 4/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0053 - val_loss: 0.0178
# Epoch 5/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0053 - val_loss: 0.0227
# Epoch 6/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0051 - val_loss: 0.0181
# Epoch 7/300
# 84/84 [==============================] - 7s 85ms/step - loss: 0.0059 - val_loss: 0.0235
# Epoch 8/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0050 - val_loss: 0.0218
# Epoch 9/300
# 84/84 [==============================] - 7s 85ms/step - loss: 0.0045 - val_loss: 0.0416
# Epoch 10/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0043 - val_loss: 0.0176
# Epoch 11/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0045 - val_loss: 0.0167
# Epoch 12/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0044 - val_loss: 0.0519
# Epoch 13/300
# 84/84 [==============================] - 7s 84ms/step - loss: 0.0044 - val_loss: 0.0168
# Epoch 14/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0043 - val_loss: 0.0424
# Epoch 15/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0043 - val_loss: 0.0192
# Epoch 16/300
# 84/84 [==============================] - 7s 84ms/step - loss: 0.0045 - val_loss: 0.0303
# Epoch 17/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0039 - val_loss: 0.0146
# Epoch 18/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0043 - val_loss: 0.0559
# Epoch 19/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0044 - val_loss: 0.0124
# Epoch 20/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0038 - val_loss: 0.0229
# Epoch 21/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0040 - val_loss: 0.0190
# Epoch 22/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0040 - val_loss: 0.0146
# Epoch 23/300
# 84/84 [==============================] - 7s 86ms/step - loss: 0.0038 - val_loss: 0.0186
# Epoch 24/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0038 - val_loss: 0.0328
# Epoch 25/300
# 84/84 [==============================] - 7s 84ms/step - loss: 0.0036 - val_loss: 0.0256
# Epoch 26/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0037 - val_loss: 0.0137
# Epoch 27/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0038 - val_loss: 0.0320
# Epoch 28/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0038 - val_loss: 0.0128
# Epoch 29/300
# 84/84 [==============================] - 7s 88ms/step - loss: 0.0038 - val_loss: 0.0141
# Epoch 30/300
# 84/84 [==============================] - 7s 84ms/step - loss: 0.0041 - val_loss: 0.0200
# Epoch 31/300
# 84/84 [==============================] - 7s 84ms/step - loss: 0.0036 - val_loss: 0.0338
# Epoch 32/300
# 84/84 [==============================] - 8s 98ms/step - loss: 0.0039 - val_loss: 0.0461
# Epoch 33/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0036 - val_loss: 0.0157
# Epoch 34/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0037 - val_loss: 0.0207
# Epoch 35/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0039 - val_loss: 0.0386
# Epoch 36/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0038 - val_loss: 0.0278
# Epoch 37/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0036 - val_loss: 0.0227
# Epoch 38/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0035 - val_loss: 0.0194
# Epoch 39/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0038 - val_loss: 0.0204
# Epoch 40/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0035 - val_loss: 0.0194
# Epoch 41/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0034 - val_loss: 0.0174
# Epoch 42/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0035 - val_loss: 0.0219
# Epoch 43/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0035 - val_loss: 0.0346
# Epoch 44/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0035 - val_loss: 0.0251
# Epoch 45/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0034 - val_loss: 0.0195
# Epoch 46/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0032 - val_loss: 0.0213
# Epoch 47/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0034 - val_loss: 0.0265
# Epoch 48/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0033 - val_loss: 0.0159
# Epoch 49/300
# 84/84 [==============================] - 7s 85ms/step - loss: 0.0035 - val_loss: 0.0281
# Epoch 50/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0033 - val_loss: 0.0194
# Epoch 51/300
# 84/84 [==============================] - 7s 84ms/step - loss: 0.0032 - val_loss: 0.0319
# Epoch 52/300
# 84/84 [==============================] - 7s 84ms/step - loss: 0.0033 - val_loss: 0.0191
# Epoch 53/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0032 - val_loss: 0.0448
# 1/1 [==============================] - 0s 39ms/step - loss: 1.0658e-15
#          MAE       MSE  MAPE
# Train  27.18  1,303.88  4.30
# Test  119.64 15,333.48 16.57
# 100%|██████████| 4/4 [36:20<00:00, 545.04s/it]

# %%
# if simul_test == 1:
# Performance plot by sequence length - 시퀀스/배치 변경에 따른 MSE 기록 -> 최적화 찾기 
seq_test = pd.DataFrame()
for key, val in Score.items():
    seq_test = pd.concat([seq_test, val.iloc[1,:].T], axis=1)

seq_test = seq_test.T
seq_test.index = predict_day_list
seq_test['MSE'].plot(figsize=(12,4))
plt.show()
