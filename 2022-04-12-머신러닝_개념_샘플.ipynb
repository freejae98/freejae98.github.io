# %% [markdown]
# <a href="https://colab.research.google.com/github/freejae98/freejae98.github.io/blob/master/2022-04-12-%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%EA%B0%9C%EB%85%90_%EC%83%98%ED%94%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, Activation, Flatten, Dropout
from keras.layers import SimpleRNN, LSTM, GRU

# %%
# GRADED FUNCTION: house_model
# def house_model(y_new):
xs = np.array([1., 2., 3., 4., 5., 6.], dtype=float)
ys = np.array([1.0, 1.50, 2.00, 2.50, 3.00, 3.50], dtype=float)

model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
# model.add(Dense(256, activation='relu'))
# model.add(Dense(128, activation='relu'))
# model.add(Dense(64, activation='relu'))
# model.add(Dense(1))

model.compile(optimizer='sgd', loss='mean_squared_error')
model.fit(xs, ys, epochs=1000)

# model.save('my_model.h5')
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 322ms/step - loss: 3.8015
# Epoch 2/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0975
# Epoch 3/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0377
# Epoch 4/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0311
# Epoch 5/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0292
# Epoch 6/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0284
# Epoch 7/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0277
# Epoch 8/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0271
# Epoch 9/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0265
# Epoch 10/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0259
# Epoch 11/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0253
# Epoch 12/1000
# ...

# %%
# prediction = house_model([7.0])
# print(prediction)

prediction = model.predict([11, 12, 13, 14]) #[0]
print(prediction)

# [[6.019281 ]
#  [6.5241513]
#  [7.029021 ]
#  [7.53389  ]]

# [[5.9996495]
#  [6.4995537]
#  [6.99946  ]
#  [7.499364 ]]
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd380e4b440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[6.019281 ]
#  [6.5241513]
#  [7.029021 ]
#  [7.53389  ]]
