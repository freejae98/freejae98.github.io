# %% [markdown]
# <a href="https://colab.research.google.com/github/freejae98/freejae98.github.io/blob/master/2022_10_18_f_ML)_2022_10_18_New_Steel_v1_5%EA%B8%B0%EA%B0%84%EB%B3%84_4%EA%B0%9C%EB%AA%A8%EB%8D%B8_%EC%A0%80%EC%9E%A5_%EB%AA%A8%EB%8D%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ignore the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# System related and data input controls
import os

# Data manipulation, visualization and useful functions
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
pd.options.display.max_rows = 50
pd.options.display.max_columns = 40
import numpy as np
from itertools import product # iterative combinations
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

# Modeling algorithms
# General(Statistics/Econometrics)
from sklearn import preprocessing
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats

# Regression
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.kernel_ridge import KernelRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor, GradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# Classification
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# Model selection
from sklearn.model_selection import train_test_split,cross_validate
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

# Evaluation metrics
# for regression
from sklearn.metrics import mean_squared_log_error, mean_squared_error,  r2_score, mean_absolute_error
# for classification
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
### Evaluation of 1 pair of set
def evaluation(Y_real, Y_pred, graph_on=False):
    loss_length = len(Y_real.values.flatten()) - len(Y_pred)
    if loss_length != 0:
        Y_real = Y_real[loss_length:]
    if graph_on == True:
        pd.concat([Y_real, pd.DataFrame(Y_pred, index=Y_real.index, columns=['prediction'])], axis=1).plot(kind='line', figsize=(20,6),
                                                                                                           xlim=(Y_real.index.min(),Y_real.index.max()),
                                                                                                           linewidth=3, fontsize=20)
        plt.title('Time Series of Target', fontsize=20)
        plt.xlabel('Index', fontsize=15)
        plt.ylabel('Target Value', fontsize=15)
    MAE = abs(Y_real.values.flatten() - Y_pred).mean()
    MSE = ((Y_real.values.flatten() - Y_pred)**2).mean()
    MAPE = (abs(Y_real.values.flatten() - Y_pred)/Y_real.values.flatten()*100).mean()
    Score = pd.DataFrame([MAE, MSE, MAPE], index=['MAE', 'MSE', 'MAPE'], columns=['Score']).T
    Residual = pd.DataFrame(Y_real.values.flatten() - Y_pred, index=Y_real.index, columns=['Error'])
    return Score, Residual
# Score_tr, Residual_tr = evaluation(Y_train, pred_tr_reg1, graph_on=True)


### Evaluation of train/test pairs
def evaluation_trte(Y_real_tr, Y_pred_tr, Y_real_te, Y_pred_te, graph_on=False):
    Score_tr, Residual_tr = evaluation(Y_real_tr, Y_pred_tr, graph_on=graph_on)
    Score_te, Residual_te = evaluation(Y_real_te, Y_pred_te, graph_on=graph_on)
    Score_trte = pd.concat([Score_tr, Score_te], axis=0)
    Score_trte.index = ['Train', 'Test']
    return Score_trte, Residual_tr, Residual_te
# Score_reg1, Resid_tr_reg1, Resid_te_reg1 = evaluation_trte(Y_train, pred_tr_reg1, Y_test, pred_te_reg1, graph_on=True)

# %%
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, Activation, Flatten, Dropout
from keras.layers import SimpleRNN, LSTM, GRU

from pickle import dump

# %%
# Data Loading
df = pd.read_excel('/content/drive/MyDrive/(Total) Data_Lake.xlsx')   #dataset_6 사용
df.set_index('Date', inplace=True)

X_colname = ['MA5']
raw_all = df[X_colname]

# raw_all = df.loc[df['MA5'] != np.nan, :]

#20%는 테스트용 구분함
# PCT = 0.2
# c_num = int(len(raw_all.index) * (1- PCT))

# criteria = raw_all.index[int(c_num)]


# raw_all = df.loc[df.index >= '2019-12-30', X_colname]

# Parameters - 시작점을 달리할 경우 정확도에 어떤 영향을 얻을 수 있는지?

start_point = '2017-1-1'     #기존 시작점 : '2019-12-30'
# start_list = ['2016-1-1', '2018-1-1', '2020-1-1', '2021-1-1']     #기존 시작점 : '2019-12-30'
criteria = '2022-08-01'     #기존 시작점 : '2021-09-01'

scaler = preprocessing.MinMaxScaler()
sequence = 15   # → optimization 진행
batch_size = 16
epoch = 300
verbose = 1  # 원래는 1
dropout_ratio = 0

#며칠이나 이후 것을 예상할 것인지 (20 = 4주 후)
predict_day = 5    #5*1 # 1주 후

predict_day_list = [5, 10, 15, 20]    #각 1,2,3,4주 후



# Feature Engineering
## Train & Test Split
# train = raw_all.loc[raw_all.index < criteria,:]

# %%
#################################################################################
#
# ----- Feature 1, GRU 버전 -------
#
#################################################################################

from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor = 'val_loss', min_delta = 0, patience = 50, mode = 'min')


####################### iterations #######################
Score = dict()

temp = 0

# batchsize_list = [i for i in range(5, 11, 5)]
for i in tqdm(predict_day_list):
    # sequence = i
    # start_point = i

    predict_day = i   #예측일 변경

    temp = temp + 1


    train = raw_all.loc[(raw_all.index >= start_point) & (raw_all.index < criteria)]

    test = raw_all.loc[raw_all.index >= criteria,:]
    print('Train_size:', train.shape, 'Test_size:', test.shape)

    print('Train_start:', train.index[0])
    print('Test_start:', test.index[0])

    # Scaling
    train_scaled = scaler.fit_transform(train)
    test_scaled = scaler.transform(test)



    ## X / Y Split
    X_train, Y_train = [], []
    for index in range(0, len(train_scaled) - sequence - predict_day):
        X_train.append(train_scaled[index: index + sequence])
        Y_train.append(train_scaled[index + sequence + predict_day])
    X_test, Y_test = [], []
    for index in range(0, len(test_scaled) - sequence - predict_day):
        X_test.append(test_scaled[index: index + sequence])
        Y_test.append(test_scaled[index + sequence + predict_day])

    ## Retype and Reshape
    X_train, Y_train = np.array(X_train), np.array(Y_train)
    X_test, Y_test = np.array(X_test), np.array(Y_test)
    print('X_train:', X_train.shape, 'Y_train:', Y_train.shape)
    print('X_test:', X_test.shape, 'Y_test:', Y_test.shape)

    # GRU
    model = Sequential()
    model.add(GRU(128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True, activation='relu'))
    model.add(Dropout(dropout_ratio)) 
    model.add(GRU(256, return_sequences=True, activation="relu"))
    model.add(Dropout(dropout_ratio)) 
    model.add(GRU(128, return_sequences=True, activation="relu"))
    model.add(Dropout(dropout_ratio)) 
    model.add(GRU(64, return_sequences=False, activation="relu"))
    model.add(Dropout(dropout_ratio)) 
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    # model.summary()
    model_fit = model.fit(X_train, Y_train, 
                          batch_size=batch_size, epochs=epoch,
                          verbose=verbose, validation_data=(X_test, Y_test), callbacks = [early_stopping])

    plt.plot(pd.DataFrame(model_fit.history))
    plt.grid(True)
    plt.show()

    # prediction
    Y_train_pred = model.predict(X_train)
    Y_test_pred = model.predict(X_test)

    # evaluation
    result = model.evaluate(X_test, Y_test_pred)
    if scaler != []:
        Y_train = scaler.inverse_transform(Y_train)
        Y_train_pred = scaler.inverse_transform(Y_train_pred)
        Y_test = scaler.inverse_transform(Y_test)
        Y_test_pred = scaler.inverse_transform(Y_test_pred)
    Score_GRU, Residual_tr, Residual_te = evaluation_trte(pd.DataFrame(Y_train), Y_train_pred.flatten(), 
                                                          pd.DataFrame(Y_test), Y_test_pred.flatten(), graph_on=True)
    display(Score_GRU)
# if simul_test == 1:
    Score[str(predict_day)] = Score_GRU



    #모델, scaler 저장하기
    model.save("/content/drive/MyDrive/ML 모델/" + "steel_" + str(temp) + "d.h5")

    dump(scaler, open("/content/drive/MyDrive/ML 모델/" + "scaler_" + str(temp) + "d.pkl", 'wb'))



# error analysis
# error_analysis(Residual_te, ['Error'], pd.DataFrame(X_train.reshape(X_train.shape[0], X_train.shape[1])), graph_on=True)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Train_size: (1455, 1) Test_size: (56, 1)
# Train_start: 2017-01-02 00:00:00
# Test_start: 2022-08-01 00:00:00
# X_train: (1435, 15, 1) Y_train: (1435, 1)
# X_test: (36, 15, 1) Y_test: (36, 1)
# Epoch 1/300
# 90/90 [==============================] - 16s 109ms/step - loss: 0.0144 - val_loss: 9.8897e-05
# Epoch 2/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0018 - val_loss: 8.5193e-04
# Epoch 3/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0016 - val_loss: 3.2931e-04
# Epoch 4/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 5/300
# 90/90 [==============================] - 8s 94ms/step - loss: 0.0014 - val_loss: 7.7846e-04
# Epoch 6/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 7/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0012 - val_loss: 8.8813e-04
# Epoch 8/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0014 - val_loss: 1.8362e-04
# Epoch 9/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 10/300
# 90/90 [==============================] - 7s 78ms/step - loss: 9.4073e-04 - val_loss: 1.0845e-04
# Epoch 11/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0011 - val_loss: 4.2019e-04
# Epoch 12/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0011 - val_loss: 2.8576e-04
# Epoch 13/300
# 90/90 [==============================] - 7s 79ms/step - loss: 9.6523e-04 - val_loss: 1.6925e-04
# Epoch 14/300
# 90/90 [==============================] - 7s 79ms/step - loss: 9.6670e-04 - val_loss: 1.4412e-04
# Epoch 15/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 16/300
# 90/90 [==============================] - 7s 79ms/step - loss: 7.4966e-04 - val_loss: 1.5731e-04
# Epoch 17/300
# 90/90 [==============================] - 7s 79ms/step - loss: 7.7372e-04 - val_loss: 0.0011
# Epoch 18/300
# 90/90 [==============================] - 7s 80ms/step - loss: 7.0816e-04 - val_loss: 1.3075e-04
# Epoch 19/300
# 90/90 [==============================] - 7s 80ms/step - loss: 8.5514e-04 - val_loss: 4.5241e-04
# Epoch 20/300
# 90/90 [==============================] - 7s 79ms/step - loss: 6.9148e-04 - val_loss: 2.6192e-04
# Epoch 21/300
# 90/90 [==============================] - 7s 80ms/step - loss: 9.4028e-04 - val_loss: 1.2069e-04
# Epoch 22/300
# 90/90 [==============================] - 7s 80ms/step - loss: 6.5572e-04 - val_loss: 3.3330e-04
# Epoch 23/300
# 90/90 [==============================] - 7s 78ms/step - loss: 7.5720e-04 - val_loss: 2.4290e-04
# Epoch 24/300
# 90/90 [==============================] - 7s 79ms/step - loss: 5.9306e-04 - val_loss: 4.6731e-04
# Epoch 25/300
# 90/90 [==============================] - 7s 79ms/step - loss: 5.9863e-04 - val_loss: 2.9339e-04
# Epoch 26/300
# 90/90 [==============================] - 9s 102ms/step - loss: 6.4260e-04 - val_loss: 6.4894e-04
# Epoch 27/300
# 90/90 [==============================] - 7s 79ms/step - loss: 6.4013e-04 - val_loss: 1.3375e-04
# Epoch 28/300
# 90/90 [==============================] - 7s 78ms/step - loss: 8.0512e-04 - val_loss: 4.1003e-04
# Epoch 29/300
# 90/90 [==============================] - 7s 79ms/step - loss: 5.8171e-04 - val_loss: 1.2463e-04
# Epoch 30/300
# 90/90 [==============================] - 7s 78ms/step - loss: 6.1375e-04 - val_loss: 1.3065e-04
# Epoch 31/300
# 90/90 [==============================] - 7s 78ms/step - loss: 6.6674e-04 - val_loss: 4.0232e-04
# Epoch 32/300
# 90/90 [==============================] - 7s 79ms/step - loss: 7.2888e-04 - val_loss: 1.2659e-04
# Epoch 33/300
# 90/90 [==============================] - 7s 80ms/step - loss: 7.5232e-04 - val_loss: 1.7638e-04
# Epoch 34/300
# 90/90 [==============================] - 7s 81ms/step - loss: 5.2172e-04 - val_loss: 2.5274e-04
# Epoch 35/300
# 90/90 [==============================] - 7s 81ms/step - loss: 5.8722e-04 - val_loss: 1.6372e-04
# Epoch 36/300
# 90/90 [==============================] - 7s 80ms/step - loss: 5.8370e-04 - val_loss: 1.3085e-04
# Epoch 37/300
# 90/90 [==============================] - 7s 79ms/step - loss: 4.9273e-04 - val_loss: 1.8858e-04
# Epoch 38/300
# 90/90 [==============================] - 7s 80ms/step - loss: 5.7252e-04 - val_loss: 1.9253e-04
# Epoch 39/300
# 90/90 [==============================] - 7s 79ms/step - loss: 6.3628e-04 - val_loss: 1.4055e-04
# Epoch 40/300
# 90/90 [==============================] - 7s 80ms/step - loss: 6.0200e-04 - val_loss: 1.3547e-04
# Epoch 41/300
# 90/90 [==============================] - 7s 79ms/step - loss: 5.8235e-04 - val_loss: 4.0020e-04
# Epoch 42/300
# 90/90 [==============================] - 7s 79ms/step - loss: 5.6606e-04 - val_loss: 1.3959e-04
# Epoch 43/300
# 90/90 [==============================] - 7s 78ms/step - loss: 5.6827e-04 - val_loss: 1.3697e-04
# Epoch 44/300
# 90/90 [==============================] - 7s 79ms/step - loss: 5.9296e-04 - val_loss: 1.7985e-04
# Epoch 45/300
# 90/90 [==============================] - 7s 78ms/step - loss: 5.3671e-04 - val_loss: 1.3082e-04
# Epoch 46/300
# 90/90 [==============================] - 7s 78ms/step - loss: 7.7502e-04 - val_loss: 1.6699e-04
# Epoch 47/300
# 90/90 [==============================] - 7s 80ms/step - loss: 5.4936e-04 - val_loss: 2.5024e-04
# Epoch 48/300
# 90/90 [==============================] - 7s 81ms/step - loss: 5.1948e-04 - val_loss: 2.9348e-04
# Epoch 49/300
# 90/90 [==============================] - 7s 79ms/step - loss: 6.0900e-04 - val_loss: 1.3370e-04
# Epoch 50/300
# 90/90 [==============================] - 7s 80ms/step - loss: 4.7501e-04 - val_loss: 1.7966e-04
# Epoch 51/300
# 90/90 [==============================] - 9s 103ms/step - loss: 6.2558e-04 - val_loss: 1.5473e-04
# 45/45 [==============================] - 2s 33ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 16ms/step - loss: 2.4672e-16
#        MAE    MSE  MAPE
# Train 8.01 169.04  1.26
# Test  6.48  59.71  1.13
#  25%|██▌       | 1/4 [06:31<19:33, 391.30s/it]
# Train_size: (1455, 1) Test_size: (56, 1)
# Train_start: 2017-01-02 00:00:00
# Test_start: 2022-08-01 00:00:00
# X_train: (1430, 15, 1) Y_train: (1430, 1)
# X_test: (31, 15, 1) Y_test: (31, 1)
# Epoch 1/300
# 90/90 [==============================] - 13s 87ms/step - loss: 0.0171 - val_loss: 4.2594e-04
# Epoch 2/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 3/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0034 - val_loss: 4.9870e-04
# Epoch 4/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 5/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 6/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0030 - val_loss: 6.2533e-04
# Epoch 7/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0027 - val_loss: 8.6454e-05
# Epoch 8/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0026 - val_loss: 9.5010e-05
# Epoch 9/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0027 - val_loss: 2.5660e-04
# Epoch 10/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 11/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 12/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0024 - val_loss: 1.9411e-04
# Epoch 13/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0023 - val_loss: 1.1054e-04
# Epoch 14/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 15/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 16/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 17/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0021 - val_loss: 3.8767e-04
# Epoch 18/300
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0022 - val_loss: 4.8897e-04
# Epoch 19/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0019 - val_loss: 1.4683e-04
# Epoch 20/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0019 - val_loss: 1.4179e-04
# Epoch 21/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0019 - val_loss: 6.3138e-04
# Epoch 22/300
# 90/90 [==============================] - 9s 103ms/step - loss: 0.0019 - val_loss: 3.3717e-04
# Epoch 23/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 24/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0019 - val_loss: 1.6111e-04
# Epoch 25/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0021 - val_loss: 8.1258e-04
# Epoch 26/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0018 - val_loss: 2.8806e-04
# Epoch 27/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0018 - val_loss: 5.2880e-04
# Epoch 28/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 29/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0022 - val_loss: 5.7933e-04
# Epoch 30/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0018 - val_loss: 1.7565e-04
# Epoch 31/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0017 - val_loss: 2.1222e-04
# Epoch 32/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0017 - val_loss: 3.3978e-04
# Epoch 33/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 34/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0019 - val_loss: 2.0640e-04
# Epoch 35/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0017 - val_loss: 2.2464e-04
# Epoch 36/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0017 - val_loss: 2.7425e-04
# Epoch 37/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0016 - val_loss: 2.3964e-04
# Epoch 38/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0019 - val_loss: 2.2001e-04
# Epoch 39/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0016 - val_loss: 2.1226e-04
# Epoch 40/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0015 - val_loss: 7.0647e-04
# Epoch 41/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0015 - val_loss: 2.4033e-04
# Epoch 42/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0016 - val_loss: 4.7579e-04
# Epoch 43/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0016 - val_loss: 2.5344e-04
# Epoch 44/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0014 - val_loss: 2.4191e-04
# Epoch 45/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0015 - val_loss: 2.5007e-04
# Epoch 46/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0015 - val_loss: 3.6986e-04
# Epoch 47/300
# 90/90 [==============================] - 9s 102ms/step - loss: 0.0016 - val_loss: 2.6504e-04
# Epoch 48/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0015 - val_loss: 6.4698e-04
# Epoch 49/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0015 - val_loss: 2.9524e-04
# Epoch 50/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0015 - val_loss: 2.5241e-04
# Epoch 51/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0016 - val_loss: 4.9673e-04
# Epoch 52/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0015 - val_loss: 2.9052e-04
# Epoch 53/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0015 - val_loss: 4.8425e-04
# Epoch 54/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0016 - val_loss: 2.9459e-04
# Epoch 55/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0016 - val_loss: 5.2671e-04
# Epoch 56/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0014 - val_loss: 2.8810e-04
# Epoch 57/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0015 - val_loss: 2.1877e-04
# 45/45 [==============================] - 2s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step - loss: 2.5786e-16
#         MAE    MSE  MAPE
# Train 15.90 536.45  2.50
# Test   7.91  84.42  1.38
#  50%|█████     | 2/4 [14:02<14:12, 426.33s/it]
# Train_size: (1455, 1) Test_size: (56, 1)
# Train_start: 2017-01-02 00:00:00
# Test_start: 2022-08-01 00:00:00
# X_train: (1425, 15, 1) Y_train: (1425, 1)
# X_test: (26, 15, 1) Y_test: (26, 1)
# Epoch 1/300
# 90/90 [==============================] - 13s 88ms/step - loss: 0.0176 - val_loss: 0.0078
# Epoch 2/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0051 - val_loss: 0.0034
# Epoch 3/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0045 - val_loss: 0.0027
# Epoch 4/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0046 - val_loss: 0.0034
# Epoch 5/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0046 - val_loss: 1.1389e-04
# Epoch 6/300
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0040 - val_loss: 0.0070
# Epoch 7/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0043 - val_loss: 0.0026
# Epoch 8/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0037 - val_loss: 4.6194e-05
# Epoch 9/300
# 90/90 [==============================] - 8s 86ms/step - loss: 0.0036 - val_loss: 3.9139e-04
# Epoch 10/300
# 90/90 [==============================] - 9s 95ms/step - loss: 0.0037 - val_loss: 6.8846e-05
# Epoch 11/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 12/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0035 - val_loss: 8.3485e-05
# Epoch 13/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0034 - val_loss: 4.7623e-04
# Epoch 14/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0045 - val_loss: 1.2675e-04
# Epoch 15/300
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0034 - val_loss: 4.2043e-04
# Epoch 16/300
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 17/300
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0033 - val_loss: 2.3620e-04
# Epoch 18/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0030 - val_loss: 7.6918e-04
# Epoch 19/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0031 - val_loss: 2.6262e-04
# Epoch 20/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0031 - val_loss: 2.7015e-04
# Epoch 21/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0035 - val_loss: 8.2060e-04
# Epoch 22/300
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0047 - val_loss: 8.4625e-04
# Epoch 23/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0028 - val_loss: 3.4072e-04
# Epoch 24/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 25/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 26/300
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0028 - val_loss: 3.8502e-04
# Epoch 27/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0030 - val_loss: 7.9128e-04
# Epoch 28/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0026 - val_loss: 1.9073e-04
# Epoch 29/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0026 - val_loss: 8.4075e-04
# Epoch 30/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 31/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 32/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 33/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0032 - val_loss: 1.4559e-04
# Epoch 34/300
# 90/90 [==============================] - 8s 93ms/step - loss: 0.0027 - val_loss: 6.3954e-04
# Epoch 35/300
# 90/90 [==============================] - 8s 90ms/step - loss: 0.0025 - val_loss: 2.5078e-04
# Epoch 36/300
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0025 - val_loss: 5.4584e-04
# Epoch 37/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0024 - val_loss: 2.4779e-04
# Epoch 38/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0025 - val_loss: 3.2956e-04
# Epoch 39/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0025 - val_loss: 5.1004e-04
# Epoch 40/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0023 - val_loss: 1.7915e-04
# Epoch 41/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 42/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0026 - val_loss: 9.5434e-04
# Epoch 43/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0023 - val_loss: 6.1412e-04
# Epoch 44/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0023 - val_loss: 1.7761e-04
# Epoch 45/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 46/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0023 - val_loss: 5.4407e-04
# Epoch 47/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0022 - val_loss: 2.9023e-04
# Epoch 48/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0023 - val_loss: 3.1090e-04
# Epoch 49/300
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0024 - val_loss: 7.8745e-04
# Epoch 50/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0024 - val_loss: 3.2546e-04
# Epoch 51/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0024 - val_loss: 2.0291e-04
# Epoch 52/300
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0024 - val_loss: 5.8605e-04
# Epoch 53/300
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0024 - val_loss: 3.2973e-04
# Epoch 54/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0024 - val_loss: 8.0896e-04
# Epoch 55/300
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0024 - val_loss: 0.0010
# Epoch 56/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0023 - val_loss: 1.5587e-04
# Epoch 57/300
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0025 - val_loss: 4.4053e-04
# Epoch 58/300
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0021 - val_loss: 1.9461e-04
# 45/45 [==============================] - 2s 32ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 62ms/step - loss: 3.0745e-16
#         MAE    MSE  MAPE
# Train 22.40 859.58  3.64
# Test   6.69  75.10  1.17
#  75%|███████▌  | 3/4 [21:14<07:09, 429.06s/it]
# Train_size: (1455, 1) Test_size: (56, 1)
# Train_start: 2017-01-02 00:00:00
# Test_start: 2022-08-01 00:00:00
# X_train: (1420, 15, 1) Y_train: (1420, 1)
# X_test: (21, 15, 1) Y_test: (21, 1)
# Epoch 1/300
# 89/89 [==============================] - 15s 89ms/step - loss: 0.0171 - val_loss: 0.0028
# Epoch 2/300
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0069 - val_loss: 0.0013
# Epoch 3/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0065 - val_loss: 0.0036
# Epoch 4/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0062 - val_loss: 0.0073
# Epoch 5/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0058 - val_loss: 3.4608e-04
# Epoch 6/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0056 - val_loss: 0.0040
# Epoch 7/300
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0053 - val_loss: 0.0019
# Epoch 8/300
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0058 - val_loss: 4.4526e-05
# Epoch 9/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0056 - val_loss: 0.0015
# Epoch 10/300
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0050 - val_loss: 0.0029
# Epoch 11/300
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 12/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0045 - val_loss: 5.3367e-04
# Epoch 13/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0057 - val_loss: 0.0047
# Epoch 14/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0053 - val_loss: 0.0027
# Epoch 15/300
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0043 - val_loss: 0.0022
# Epoch 16/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0041 - val_loss: 0.0045
# Epoch 17/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 18/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0039 - val_loss: 2.0645e-04
# Epoch 19/300
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0038 - val_loss: 0.0015
# Epoch 20/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0039 - val_loss: 2.0357e-04
# Epoch 21/300
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0039 - val_loss: 0.0015
# Epoch 22/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0039 - val_loss: 0.0043
# Epoch 23/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0038 - val_loss: 3.0732e-04
# Epoch 24/300
# 89/89 [==============================] - 8s 92ms/step - loss: 0.0037 - val_loss: 3.5564e-04
# Epoch 25/300
# 89/89 [==============================] - 8s 93ms/step - loss: 0.0040 - val_loss: 0.0010
# Epoch 26/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0036 - val_loss: 8.5291e-04
# Epoch 27/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0038 - val_loss: 1.4425e-04
# Epoch 28/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0036 - val_loss: 7.5873e-04
# Epoch 29/300
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0035 - val_loss: 0.0029
# Epoch 30/300
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0033 - val_loss: 1.2803e-04
# Epoch 31/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0040 - val_loss: 2.1298e-04
# Epoch 32/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 33/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0036 - val_loss: 4.8570e-04
# Epoch 34/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0033 - val_loss: 1.5506e-04
# Epoch 35/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0033 - val_loss: 9.4791e-04
# Epoch 36/300
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0036 - val_loss: 2.3774e-04
# Epoch 37/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0035 - val_loss: 5.3229e-04
# Epoch 38/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0031 - val_loss: 6.7079e-04
# Epoch 39/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0033 - val_loss: 1.3305e-04
# Epoch 40/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0033 - val_loss: 1.3588e-04
# Epoch 41/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0032 - val_loss: 8.6962e-05
# Epoch 42/300
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 43/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0032 - val_loss: 4.9724e-04
# Epoch 44/300
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0031 - val_loss: 8.7772e-04
# Epoch 45/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0035 - val_loss: 5.3383e-04
# Epoch 46/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0031 - val_loss: 5.3175e-04
# Epoch 47/300
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0037 - val_loss: 4.6738e-04
# Epoch 48/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0030 - val_loss: 4.2198e-04
# Epoch 49/300
# 89/89 [==============================] - 8s 89ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 50/300
# 89/89 [==============================] - 9s 96ms/step - loss: 0.0029 - val_loss: 9.9136e-05
# Epoch 51/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0031 - val_loss: 1.2992e-04
# Epoch 52/300
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0029 - val_loss: 5.3601e-04
# Epoch 53/300
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0029 - val_loss: 5.4919e-04
# Epoch 54/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0030 - val_loss: 4.2138e-04
# Epoch 55/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0029 - val_loss: 7.1598e-05
# Epoch 56/300
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0029 - val_loss: 6.6590e-05
# Epoch 57/300
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0026 - val_loss: 6.7404e-04
# Epoch 58/300
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0030 - val_loss: 1.5495e-04
# 45/45 [==============================] - 2s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 2.1147e-16
#         MAE    MSE  MAPE
# Train 24.00 994.10  3.90
# Test   6.35  59.79  1.12
# 100%|██████████| 4/4 [28:28<00:00, 427.17s/it]

# %%
# if simul_test == 1:
# Performance plot by sequence length - 시퀀스/배치 변경에 따른 MSE 기록 -> 최적화 찾기 
seq_test = pd.DataFrame()
for key, val in Score.items():
    seq_test = pd.concat([seq_test, val.iloc[1,:].T], axis=1)

seq_test = seq_test.T
seq_test.index = predict_day_list
seq_test['MSE'].plot(figsize=(12,4))
plt.show()
