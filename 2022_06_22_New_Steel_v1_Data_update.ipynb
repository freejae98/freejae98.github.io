# %% [markdown]
# <a href="https://colab.research.google.com/github/freejae98/freejae98.github.io/blob/master/2022_06_22_New_Steel_v1_Data_update.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ignore the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# System related and data input controls
import os

# Data manipulation, visualization and useful functions
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
pd.options.display.max_rows = 50
pd.options.display.max_columns = 40
import numpy as np
from itertools import product # iterative combinations
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

# Modeling algorithms
# General(Statistics/Econometrics)
from sklearn import preprocessing
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats

# Regression
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.kernel_ridge import KernelRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor, GradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# Classification
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# Model selection
from sklearn.model_selection import train_test_split,cross_validate
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

# Evaluation metrics
# for regression
from sklearn.metrics import mean_squared_log_error, mean_squared_error,  r2_score, mean_absolute_error
# for classification
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
### Evaluation of 1 pair of set
def evaluation(Y_real, Y_pred, graph_on=False):
    loss_length = len(Y_real.values.flatten()) - len(Y_pred)
    if loss_length != 0:
        Y_real = Y_real[loss_length:]
    if graph_on == True:
        pd.concat([Y_real, pd.DataFrame(Y_pred, index=Y_real.index, columns=['prediction'])], axis=1).plot(kind='line', figsize=(20,6),
                                                                                                           xlim=(Y_real.index.min(),Y_real.index.max()),
                                                                                                           linewidth=3, fontsize=20)
        plt.title('Time Series of Target', fontsize=20)
        plt.xlabel('Index', fontsize=15)
        plt.ylabel('Target Value', fontsize=15)
    MAE = abs(Y_real.values.flatten() - Y_pred).mean()
    MSE = ((Y_real.values.flatten() - Y_pred)**2).mean()
    MAPE = (abs(Y_real.values.flatten() - Y_pred)/Y_real.values.flatten()*100).mean()
    Score = pd.DataFrame([MAE, MSE, MAPE], index=['MAE', 'MSE', 'MAPE'], columns=['Score']).T
    Residual = pd.DataFrame(Y_real.values.flatten() - Y_pred, index=Y_real.index, columns=['Error'])
    return Score, Residual
# Score_tr, Residual_tr = evaluation(Y_train, pred_tr_reg1, graph_on=True)


### Evaluation of train/test pairs
def evaluation_trte(Y_real_tr, Y_pred_tr, Y_real_te, Y_pred_te, graph_on=False):
    Score_tr, Residual_tr = evaluation(Y_real_tr, Y_pred_tr, graph_on=graph_on)
    Score_te, Residual_te = evaluation(Y_real_te, Y_pred_te, graph_on=graph_on)
    Score_trte = pd.concat([Score_tr, Score_te], axis=0)
    Score_trte.index = ['Train', 'Test']
    return Score_trte, Residual_tr, Residual_te
# Score_reg1, Resid_tr_reg1, Resid_te_reg1 = evaluation_trte(Y_train, pred_tr_reg1, Y_test, pred_te_reg1, graph_on=True)

# %%
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, Activation, Flatten, Dropout
from keras.layers import SimpleRNN, LSTM, GRU

# %%
# Data Loading
df = pd.read_excel('/content/data_completed.xlsx')   #dataset_6 사용
df.set_index('Date', inplace=True)

X_colname = ['1)열연-천진']
raw_all = df[X_colname]

# raw_all = df.loc[df['MA5'] != np.nan, :]

#20%는 테스트용 구분함
# PCT = 0.2
# c_num = int(len(raw_all.index) * (1- PCT))

# criteria = raw_all.index[int(c_num)]


# raw_all = df.loc[df.index >= '2019-12-30', X_colname]

# Parameters - 시작점을 달리할 경우 정확도에 어떤 영향을 얻을 수 있는지?

# start_point = '2018-12-30'     #기존 시작점 : '2019-12-30'
start_list = ['2016-1-1', '2018-1-1', '2020-1-1', '2021-1-1']     #기존 시작점 : '2019-12-30'
criteria = '2022-03-01'     #기존 시작점 : '2021-09-01'

scaler = preprocessing.MinMaxScaler()
sequence = 15   # → optimization 진행
batch_size = 16
epoch = 1000
verbose = 1  # 원래는 1
dropout_ratio = 0

#며칠이나 이후 것을 예상할 것인지 (20 = 4주 후)
predict_day = 5*1 # 1주 후


# Feature Engineering
## Train & Test Split
# train = raw_all.loc[raw_all.index < criteria,:]

# %%
#################################################################################
#
# ----- Feature 1, GRU 버전 -------
#
#################################################################################

from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor = 'val_loss', min_delta = 0, patience = 50, mode = 'min')


####################### iterations #######################
Score = dict()
# batchsize_list = [i for i in range(5, 11, 5)]
for i in tqdm(start_list):
    # sequence = i
    start_point = i



    train = raw_all.loc[(raw_all.index >= start_point) & (raw_all.index < criteria)]

    test = raw_all.loc[raw_all.index >= criteria,:]
    print('Train_size:', train.shape, 'Test_size:', test.shape)

    print('Train_start:', train.index[0])
    print('Test_start:', test.index[0])

    # Scaling
    train_scaled = scaler.fit_transform(train)
    test_scaled = scaler.transform(test)



    ## X / Y Split
    X_train, Y_train = [], []
    for index in range(0, len(train_scaled) - sequence - predict_day):
        X_train.append(train_scaled[index: index + sequence])
        Y_train.append(train_scaled[index + sequence + predict_day])
    X_test, Y_test = [], []
    for index in range(0, len(test_scaled) - sequence - predict_day):
        X_test.append(test_scaled[index: index + sequence])
        Y_test.append(test_scaled[index + sequence + predict_day])

    ## Retype and Reshape
    X_train, Y_train = np.array(X_train), np.array(Y_train)
    X_test, Y_test = np.array(X_test), np.array(Y_test)
    print('X_train:', X_train.shape, 'Y_train:', Y_train.shape)
    print('X_test:', X_test.shape, 'Y_test:', Y_test.shape)

    # GRU
    model = Sequential()
    model.add(GRU(128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True, activation='relu'))
    model.add(Dropout(dropout_ratio)) 
    model.add(GRU(256, return_sequences=True, activation="relu"))
    model.add(Dropout(dropout_ratio)) 
    model.add(GRU(128, return_sequences=True, activation="relu"))
    model.add(Dropout(dropout_ratio)) 
    model.add(GRU(64, return_sequences=False, activation="relu"))
    model.add(Dropout(dropout_ratio)) 
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    # model.summary()
    model_fit = model.fit(X_train, Y_train, 
                          batch_size=batch_size, epochs=epoch,
                          verbose=verbose, validation_data=(X_test, Y_test), callbacks = [early_stopping])

    plt.plot(pd.DataFrame(model_fit.history))
    plt.grid(True)
    plt.show()

    # prediction
    Y_train_pred = model.predict(X_train)
    Y_test_pred = model.predict(X_test)

    # evaluation
    result = model.evaluate(X_test, Y_test_pred)
    if scaler != []:
        Y_train = scaler.inverse_transform(Y_train)
        Y_train_pred = scaler.inverse_transform(Y_train_pred)
        Y_test = scaler.inverse_transform(Y_test)
        Y_test_pred = scaler.inverse_transform(Y_test_pred)
    Score_GRU, Residual_tr, Residual_te = evaluation_trte(pd.DataFrame(Y_train), Y_train_pred.flatten(), 
                                                          pd.DataFrame(Y_test), Y_test_pred.flatten(), graph_on=True)
    display(Score_GRU)
    # if simul_test == 1:
    Score[str(start_point)] = Score_GRU

# error analysis
# error_analysis(Residual_te, ['Error'], pd.DataFrame(X_train.reshape(X_train.shape[0], X_train.shape[1])), graph_on=True)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Train_size: (1607, 1) Test_size: (68, 1)
# Train_start: 2016-01-01 00:00:00
# Test_start: 2022-03-01 00:00:00
# X_train: (1587, 15, 1) Y_train: (1587, 1)
# X_test: (48, 15, 1) Y_test: (48, 1)
# Epoch 1/1000
# 100/100 [==============================] - 19s 85ms/step - loss: 0.0146 - val_loss: 0.0016
# Epoch 2/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 3/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 4/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 5/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 6/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 7/1000
# 100/100 [==============================] - 8s 77ms/step - loss: 0.0015 - val_loss: 9.1273e-04
# Epoch 8/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 9/1000
# 100/100 [==============================] - 9s 95ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 10/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 11/1000
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 12/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 13/1000
# 100/100 [==============================] - 8s 77ms/step - loss: 0.0011 - val_loss: 9.3479e-04
# Epoch 14/1000
# 100/100 [==============================] - 8s 77ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 15/1000
# 100/100 [==============================] - 9s 88ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 16/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0011 - val_loss: 8.8917e-04
# Epoch 17/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0010 - val_loss: 8.1215e-04
# Epoch 18/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 9.5025e-04 - val_loss: 0.0011
# Epoch 19/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 9.6914e-04 - val_loss: 0.0013
# Epoch 20/1000
# 100/100 [==============================] - 8s 77ms/step - loss: 0.0010 - val_loss: 7.3672e-04
# Epoch 21/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 22/1000
# 100/100 [==============================] - 8s 77ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 23/1000
# 100/100 [==============================] - 8s 77ms/step - loss: 9.1867e-04 - val_loss: 0.0011
# Epoch 24/1000
# 100/100 [==============================] - 8s 77ms/step - loss: 9.6239e-04 - val_loss: 0.0024
# Epoch 25/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 9.4224e-04 - val_loss: 9.3712e-04
# Epoch 26/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 9.6186e-04 - val_loss: 7.4588e-04
# Epoch 27/1000
# 100/100 [==============================] - 8s 77ms/step - loss: 9.0569e-04 - val_loss: 9.7723e-04
# Epoch 28/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 29/1000
# 100/100 [==============================] - 8s 77ms/step - loss: 0.0010 - val_loss: 0.0032
# Epoch 30/1000
# 100/100 [==============================] - 8s 77ms/step - loss: 8.7789e-04 - val_loss: 0.0019
# Epoch 31/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 9.6036e-04 - val_loss: 0.0013
# Epoch 32/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 9.2626e-04 - val_loss: 0.0025
# Epoch 33/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 8.9701e-04 - val_loss: 8.7511e-04
# Epoch 34/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 9.9340e-04 - val_loss: 7.4198e-04
# Epoch 35/1000
# 100/100 [==============================] - 8s 77ms/step - loss: 9.5076e-04 - val_loss: 0.0011
# Epoch 36/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 9.0881e-04 - val_loss: 0.0021
# Epoch 37/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 38/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 9.1050e-04 - val_loss: 0.0017
# Epoch 39/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 8.4855e-04 - val_loss: 0.0027
# Epoch 40/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 8.8365e-04 - val_loss: 9.1965e-04
# Epoch 41/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 8.9453e-04 - val_loss: 8.6498e-04
# Epoch 42/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 43/1000
# 100/100 [==============================] - 9s 89ms/step - loss: 9.5055e-04 - val_loss: 0.0013
# Epoch 44/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 9.6379e-04 - val_loss: 9.1476e-04
# Epoch 45/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 9.3985e-04 - val_loss: 8.8141e-04
# Epoch 46/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 9.6793e-04 - val_loss: 9.3230e-04
# Epoch 47/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 48/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 9.9221e-04 - val_loss: 0.0012
# Epoch 49/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0011 - val_loss: 7.7323e-04
# Epoch 50/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 9.6403e-04 - val_loss: 7.7768e-04
# Epoch 51/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 8.7863e-04 - val_loss: 0.0020
# Epoch 52/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 8.4649e-04 - val_loss: 0.0024
# Epoch 53/1000
# 100/100 [==============================] - 8s 77ms/step - loss: 9.6965e-04 - val_loss: 7.6464e-04
# Epoch 54/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 9.4541e-04 - val_loss: 0.0010
# Epoch 55/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 8.1774e-04 - val_loss: 0.0022
# Epoch 56/1000
# 100/100 [==============================] - 8s 80ms/step - loss: 8.6515e-04 - val_loss: 0.0028
# Epoch 57/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 8.5188e-04 - val_loss: 0.0017
# Epoch 58/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 9.4275e-04 - val_loss: 0.0014
# Epoch 59/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 9.1791e-04 - val_loss: 0.0022
# Epoch 60/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 9.1473e-04 - val_loss: 0.0033
# Epoch 61/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 9.5473e-04 - val_loss: 8.5852e-04
# Epoch 62/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 8.9108e-04 - val_loss: 0.0035
# Epoch 63/1000
# 100/100 [==============================] - 8s 80ms/step - loss: 9.2436e-04 - val_loss: 0.0021
# Epoch 64/1000
# 100/100 [==============================] - 8s 78ms/step - loss: 8.6133e-04 - val_loss: 0.0012
# Epoch 65/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 8.7978e-04 - val_loss: 8.3356e-04
# Epoch 66/1000
# 100/100 [==============================] - 8s 77ms/step - loss: 8.3178e-04 - val_loss: 0.0015
# Epoch 67/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 7.7200e-04 - val_loss: 0.0013
# Epoch 68/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 8.4684e-04 - val_loss: 0.0015
# Epoch 69/1000
# 100/100 [==============================] - 8s 79ms/step - loss: 8.4224e-04 - val_loss: 0.0013
# Epoch 70/1000
# 100/100 [==============================] - 8s 80ms/step - loss: 8.5873e-04 - val_loss: 7.4060e-04
# 2/2 [==============================] - 1s 25ms/step - loss: 1.1102e-15
#         MAE    MSE  MAPE
# Train 17.39 575.17  2.86
# Test  17.05 426.04  2.16
#  25%|██▌       | 1/4 [09:28<28:26, 568.73s/it]
# Train_size: (1086, 1) Test_size: (68, 1)
# Train_start: 2018-01-01 00:00:00
# Test_start: 2022-03-01 00:00:00
# X_train: (1066, 15, 1) Y_train: (1066, 1)
# X_test: (48, 15, 1) Y_test: (48, 1)
# Epoch 1/1000
# 67/67 [==============================] - 12s 97ms/step - loss: 0.0167 - val_loss: 0.0039
# Epoch 2/1000
# 67/67 [==============================] - 6s 82ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 3/1000
# 67/67 [==============================] - 5s 79ms/step - loss: 0.0023 - val_loss: 0.0042
# Epoch 4/1000
# 67/67 [==============================] - 5s 79ms/step - loss: 0.0022 - val_loss: 0.0031
# Epoch 5/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 6/1000
# 67/67 [==============================] - 5s 78ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 7/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0019 - val_loss: 0.0038
# Epoch 8/1000
# 67/67 [==============================] - 5s 79ms/step - loss: 0.0019 - val_loss: 0.0043
# Epoch 9/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0019 - val_loss: 0.0038
# Epoch 10/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 11/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 12/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 13/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 14/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 15/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0016 - val_loss: 0.0041
# Epoch 16/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 17/1000
# 67/67 [==============================] - 5s 78ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 18/1000
# 67/67 [==============================] - 5s 79ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 19/1000
# 67/67 [==============================] - 5s 79ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 20/1000
# 67/67 [==============================] - 5s 78ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 21/1000
# 67/67 [==============================] - 5s 79ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 22/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 23/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 24/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 25/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 26/1000
# 67/67 [==============================] - 5s 79ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 27/1000
# 67/67 [==============================] - 5s 79ms/step - loss: 0.0014 - val_loss: 0.0028
# Epoch 28/1000
# 67/67 [==============================] - 5s 79ms/step - loss: 0.0015 - val_loss: 0.0051
# Epoch 29/1000
# 67/67 [==============================] - 5s 79ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 30/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0015 - val_loss: 0.0049
# Epoch 31/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 32/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 33/1000
# 67/67 [==============================] - 6s 87ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 34/1000
# 67/67 [==============================] - 6s 83ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 35/1000
# 67/67 [==============================] - 6s 82ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 36/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 37/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 38/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0014 - val_loss: 0.0048
# Epoch 39/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 40/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 41/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 42/1000
# 67/67 [==============================] - 5s 82ms/step - loss: 0.0014 - val_loss: 0.0077
# Epoch 43/1000
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 44/1000
# 67/67 [==============================] - 5s 82ms/step - loss: 0.0014 - val_loss: 0.0044
# Epoch 45/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 46/1000
# 67/67 [==============================] - 5s 79ms/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 47/1000
# 67/67 [==============================] - 5s 79ms/step - loss: 0.0013 - val_loss: 0.0041
# Epoch 48/1000
# 67/67 [==============================] - 5s 79ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 49/1000
# 67/67 [==============================] - 5s 79ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 50/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 51/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 52/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 53/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 54/1000
# 67/67 [==============================] - 6s 82ms/step - loss: 0.0013 - val_loss: 0.0038
# Epoch 55/1000
# 67/67 [==============================] - 6s 83ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 56/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 57/1000
# 67/67 [==============================] - 5s 82ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 58/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0013 - val_loss: 0.0079
# Epoch 59/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 60/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 61/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 62/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 63/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0014 - val_loss: 0.0028
# Epoch 64/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 65/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 66/1000
# 67/67 [==============================] - 5s 82ms/step - loss: 0.0014 - val_loss: 0.0046
# Epoch 67/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 68/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 69/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 70/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 71/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 72/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 73/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 74/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 75/1000
# 67/67 [==============================] - 5s 80ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 76/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0013 - val_loss: 0.0047
# Epoch 77/1000
# 67/67 [==============================] - 6s 83ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 78/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 79/1000
# 67/67 [==============================] - 6s 82ms/step - loss: 0.0012 - val_loss: 0.0047
# Epoch 80/1000
# 67/67 [==============================] - 5s 82ms/step - loss: 0.0014 - val_loss: 0.0028
# Epoch 81/1000
# 67/67 [==============================] - 6s 86ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 82/1000
# 67/67 [==============================] - 5s 82ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 83/1000
# 67/67 [==============================] - 6s 85ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 84/1000
# 67/67 [==============================] - 6s 95ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 85/1000
# 67/67 [==============================] - 6s 83ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 86/1000
# 67/67 [==============================] - 6s 83ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 87/1000
# 67/67 [==============================] - 6s 83ms/step - loss: 0.0013 - val_loss: 0.0042
# Epoch 88/1000
# 67/67 [==============================] - 6s 85ms/step - loss: 0.0013 - val_loss: 0.0042
# Epoch 89/1000
# 67/67 [==============================] - 6s 85ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 90/1000
# 67/67 [==============================] - 6s 83ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 91/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0012 - val_loss: 0.0075
# Epoch 92/1000
# 67/67 [==============================] - 6s 85ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 93/1000
# 67/67 [==============================] - 6s 84ms/step - loss: 0.0012 - val_loss: 0.0065
# Epoch 94/1000
# 67/67 [==============================] - 6s 83ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 95/1000
# 67/67 [==============================] - 6s 90ms/step - loss: 0.0013 - val_loss: 0.0044
# Epoch 96/1000
# 67/67 [==============================] - 6s 85ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 97/1000
# 67/67 [==============================] - 6s 83ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 98/1000
# 67/67 [==============================] - 6s 85ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 99/1000
# 67/67 [==============================] - 6s 82ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 100/1000
# 67/67 [==============================] - 6s 83ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 101/1000
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 102/1000
# 67/67 [==============================] - 6s 85ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 103/1000
# 67/67 [==============================] - 6s 84ms/step - loss: 0.0012 - val_loss: 0.0049
# Epoch 104/1000
# 67/67 [==============================] - 6s 88ms/step - loss: 0.0013 - val_loss: 0.0057
# Epoch 105/1000
# 67/67 [==============================] - 6s 85ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 106/1000
# 67/67 [==============================] - 5s 82ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 107/1000
# 67/67 [==============================] - 6s 83ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 108/1000
# 67/67 [==============================] - 5s 82ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 109/1000
# 67/67 [==============================] - 6s 87ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 110/1000
# 67/67 [==============================] - 6s 89ms/step - loss: 0.0011 - val_loss: 0.0070
# Epoch 111/1000
# 67/67 [==============================] - 6s 91ms/step - loss: 0.0012 - val_loss: 0.0020
# 2/2 [==============================] - 1s 26ms/step - loss: 7.4015e-16
#         MAE    MSE  MAPE
# Train 12.92 394.78  1.93
# Test  19.74 687.14  2.56
#  50%|█████     | 2/4 [19:59<20:10, 605.35s/it]
# Train_size: (564, 1) Test_size: (68, 1)
# Train_start: 2020-01-01 00:00:00
# Test_start: 2022-03-01 00:00:00
# X_train: (544, 15, 1) Y_train: (544, 1)
# X_test: (48, 15, 1) Y_test: (48, 1)
# Epoch 1/1000
# 34/34 [==============================] - 8s 104ms/step - loss: 0.0496 - val_loss: 0.0023
# Epoch 2/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0039 - val_loss: 0.0035
# Epoch 3/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0036 - val_loss: 0.0055
# Epoch 4/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 5/1000
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0041 - val_loss: 0.0036
# Epoch 6/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0040 - val_loss: 0.0034
# Epoch 7/1000
# 34/34 [==============================] - 3s 80ms/step - loss: 0.0030 - val_loss: 0.0062
# Epoch 8/1000
# 34/34 [==============================] - 3s 82ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 9/1000
# 34/34 [==============================] - 3s 78ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 10/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0029 - val_loss: 0.0044
# Epoch 11/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 12/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 13/1000
# 34/34 [==============================] - 3s 90ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 14/1000
# 34/34 [==============================] - 3s 87ms/step - loss: 0.0029 - val_loss: 0.0040
# Epoch 15/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 16/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 17/1000
# 34/34 [==============================] - 3s 83ms/step - loss: 0.0029 - val_loss: 0.0037
# Epoch 18/1000
# 34/34 [==============================] - 3s 79ms/step - loss: 0.0027 - val_loss: 0.0043
# Epoch 19/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 20/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 21/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 22/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0027 - val_loss: 0.0042
# Epoch 23/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0034 - val_loss: 0.0092
# Epoch 24/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 25/1000
# 34/34 [==============================] - 3s 79ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 26/1000
# 34/34 [==============================] - 3s 77ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 27/1000
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 28/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 29/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 30/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0025 - val_loss: 0.0051
# Epoch 31/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 32/1000
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 33/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 34/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 35/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0029 - val_loss: 0.0066
# Epoch 36/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 37/1000
# 34/34 [==============================] - 3s 79ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 38/1000
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 39/1000
# 34/34 [==============================] - 3s 84ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 40/1000
# 34/34 [==============================] - 3s 82ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 41/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 42/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 43/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0028 - val_loss: 0.0042
# Epoch 44/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 45/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 46/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 47/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 48/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 49/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 50/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0024 - val_loss: 0.0056
# Epoch 51/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 52/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0024 - val_loss: 0.0044
# Epoch 53/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 54/1000
# 34/34 [==============================] - 3s 76ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 55/1000
# 34/34 [==============================] - 3s 81ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 56/1000
# 34/34 [==============================] - 3s 76ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 57/1000
# 34/34 [==============================] - 3s 80ms/step - loss: 0.0023 - val_loss: 0.0033
# Epoch 58/1000
# 34/34 [==============================] - 3s 78ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 59/1000
# 34/34 [==============================] - 3s 78ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 60/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 61/1000
# 34/34 [==============================] - 3s 76ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 62/1000
# 34/34 [==============================] - 2s 74ms/step - loss: 0.0022 - val_loss: 0.0055
# Epoch 63/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 64/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 65/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 66/1000
# 34/34 [==============================] - 3s 77ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 67/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 68/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 69/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 70/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 71/1000
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 72/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 73/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 74/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0023 - val_loss: 0.0041
# Epoch 75/1000
# 34/34 [==============================] - 2s 74ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 76/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 77/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 78/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 79/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 80/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 81/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0021 - val_loss: 0.0044
# Epoch 82/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 83/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 84/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 85/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 86/1000
# 34/34 [==============================] - 3s 78ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 87/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 88/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 89/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 90/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 91/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 92/1000
# 34/34 [==============================] - 3s 76ms/step - loss: 0.0020 - val_loss: 0.0033
# Epoch 93/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 94/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0019 - val_loss: 0.0035
# Epoch 95/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0022 - val_loss: 0.0034
# Epoch 96/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 97/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0025 - val_loss: 0.0100
# Epoch 98/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 99/1000
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0021 - val_loss: 0.0050
# Epoch 100/1000
# 34/34 [==============================] - 4s 108ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 101/1000
# 34/34 [==============================] - 3s 77ms/step - loss: 0.0020 - val_loss: 0.0047
# Epoch 102/1000
# 34/34 [==============================] - 3s 78ms/step - loss: 0.0019 - val_loss: 0.0034
# Epoch 103/1000
# 34/34 [==============================] - 3s 85ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 104/1000
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0020 - val_loss: 0.0037
# Epoch 105/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 106/1000
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 107/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 108/1000
# 34/34 [==============================] - 3s 76ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 109/1000
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0021 - val_loss: 0.0034
# Epoch 110/1000
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0019 - val_loss: 0.0034
# Epoch 111/1000
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 112/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 113/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 114/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 115/1000
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 116/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 117/1000
# 34/34 [==============================] - 3s 79ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 118/1000
# 34/34 [==============================] - 3s 77ms/step - loss: 0.0018 - val_loss: 0.0040
# Epoch 119/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 120/1000
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 121/1000
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 122/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 123/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0018 - val_loss: 0.0055
# Epoch 124/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0018 - val_loss: 0.0036
# Epoch 125/1000
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 126/1000
# 34/34 [==============================] - 3s 73ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 127/1000
# 34/34 [==============================] - 3s 83ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 128/1000
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0017 - val_loss: 0.0051
# 2/2 [==============================] - 1s 29ms/step - loss: 1.6838e-15
#         MAE      MSE  MAPE
# Train 18.50   721.97  2.50
# Test  36.67 1,774.31  4.73
#  75%|███████▌  | 3/4 [25:36<08:02, 482.71s/it]
# Train_size: (302, 1) Test_size: (68, 1)
# Train_start: 2021-01-01 00:00:00
# Test_start: 2022-03-01 00:00:00
# X_train: (282, 15, 1) Y_train: (282, 1)
# X_test: (48, 15, 1) Y_test: (48, 1)
# Epoch 1/1000
# 18/18 [==============================] - 8s 125ms/step - loss: 0.0717 - val_loss: 0.0106
# Epoch 2/1000
# 18/18 [==============================] - 2s 100ms/step - loss: 0.0204 - val_loss: 0.0158
# Epoch 3/1000
# 18/18 [==============================] - 2s 91ms/step - loss: 0.0146 - val_loss: 0.0095
# Epoch 4/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0121 - val_loss: 0.0150
# Epoch 5/1000
# 18/18 [==============================] - 2s 90ms/step - loss: 0.0127 - val_loss: 0.0089
# Epoch 6/1000
# 18/18 [==============================] - 2s 89ms/step - loss: 0.0117 - val_loss: 0.0178
# Epoch 7/1000
# 18/18 [==============================] - 2s 89ms/step - loss: 0.0124 - val_loss: 0.0146
# Epoch 8/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0113 - val_loss: 0.0133
# Epoch 9/1000
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0111 - val_loss: 0.0145
# Epoch 10/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0105 - val_loss: 0.0164
# Epoch 11/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0110 - val_loss: 0.0189
# Epoch 12/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0104 - val_loss: 0.0098
# Epoch 13/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0099 - val_loss: 0.0077
# Epoch 14/1000
# 18/18 [==============================] - 2s 90ms/step - loss: 0.0099 - val_loss: 0.0044
# Epoch 15/1000
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0096 - val_loss: 0.0073
# Epoch 16/1000
# 18/18 [==============================] - 2s 90ms/step - loss: 0.0093 - val_loss: 0.0073
# Epoch 17/1000
# 18/18 [==============================] - 2s 89ms/step - loss: 0.0105 - val_loss: 0.0076
# Epoch 18/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0088 - val_loss: 0.0069
# Epoch 19/1000
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0090 - val_loss: 0.0094
# Epoch 20/1000
# 18/18 [==============================] - 2s 88ms/step - loss: 0.0084 - val_loss: 0.0052
# Epoch 21/1000
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0088 - val_loss: 0.0104
# Epoch 22/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0098 - val_loss: 0.0069
# Epoch 23/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0091 - val_loss: 0.0073
# Epoch 24/1000
# 18/18 [==============================] - 2s 88ms/step - loss: 0.0079 - val_loss: 0.0042
# Epoch 25/1000
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0082 - val_loss: 0.0062
# Epoch 26/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0080 - val_loss: 0.0092
# Epoch 27/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0077 - val_loss: 0.0062
# Epoch 28/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0084 - val_loss: 0.0166
# Epoch 29/1000
# 18/18 [==============================] - 2s 89ms/step - loss: 0.0076 - val_loss: 0.0123
# Epoch 30/1000
# 18/18 [==============================] - 2s 88ms/step - loss: 0.0078 - val_loss: 0.0067
# Epoch 31/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0083 - val_loss: 0.0044
# Epoch 32/1000
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0091 - val_loss: 0.0136
# Epoch 33/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0098 - val_loss: 0.0108
# Epoch 34/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0074 - val_loss: 0.0098
# Epoch 35/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0077 - val_loss: 0.0055
# Epoch 36/1000
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0080 - val_loss: 0.0062
# Epoch 37/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0073 - val_loss: 0.0072
# Epoch 38/1000
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0074 - val_loss: 0.0082
# Epoch 39/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0069 - val_loss: 0.0132
# Epoch 40/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0073 - val_loss: 0.0047
# Epoch 41/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0071 - val_loss: 0.0074
# Epoch 42/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0067 - val_loss: 0.0057
# Epoch 43/1000
# 18/18 [==============================] - 2s 89ms/step - loss: 0.0068 - val_loss: 0.0063
# Epoch 44/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0067 - val_loss: 0.0078
# Epoch 45/1000
# 18/18 [==============================] - 2s 89ms/step - loss: 0.0064 - val_loss: 0.0076
# Epoch 46/1000
# 18/18 [==============================] - 2s 88ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 47/1000
# 18/18 [==============================] - 2s 88ms/step - loss: 0.0066 - val_loss: 0.0052
# Epoch 48/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0084 - val_loss: 0.0114
# Epoch 49/1000
# 18/18 [==============================] - 2s 92ms/step - loss: 0.0071 - val_loss: 0.0048
# Epoch 50/1000
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0071 - val_loss: 0.0065
# Epoch 51/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0066 - val_loss: 0.0095
# Epoch 52/1000
# 18/18 [==============================] - 2s 90ms/step - loss: 0.0065 - val_loss: 0.0103
# Epoch 53/1000
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0062 - val_loss: 0.0083
# Epoch 54/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0061 - val_loss: 0.0080
# Epoch 55/1000
# 18/18 [==============================] - 2s 88ms/step - loss: 0.0063 - val_loss: 0.0039
# Epoch 56/1000
# 18/18 [==============================] - 2s 89ms/step - loss: 0.0071 - val_loss: 0.0127
# Epoch 57/1000
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0061 - val_loss: 0.0089
# Epoch 58/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0061 - val_loss: 0.0065
# Epoch 59/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0063 - val_loss: 0.0054
# Epoch 60/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0064 - val_loss: 0.0096
# Epoch 61/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0062 - val_loss: 0.0041
# Epoch 62/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0065 - val_loss: 0.0067
# Epoch 63/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0057 - val_loss: 0.0046
# Epoch 64/1000
# 18/18 [==============================] - 2s 91ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 65/1000
# 18/18 [==============================] - 2s 95ms/step - loss: 0.0066 - val_loss: 0.0048
# Epoch 66/1000
# 18/18 [==============================] - 2s 95ms/step - loss: 0.0061 - val_loss: 0.0064
# Epoch 67/1000
# 18/18 [==============================] - 2s 90ms/step - loss: 0.0061 - val_loss: 0.0045
# Epoch 68/1000
# 18/18 [==============================] - 2s 88ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 69/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0061 - val_loss: 0.0077
# Epoch 70/1000
# 18/18 [==============================] - 2s 88ms/step - loss: 0.0059 - val_loss: 0.0066
# Epoch 71/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0063 - val_loss: 0.0053
# Epoch 72/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0062 - val_loss: 0.0065
# Epoch 73/1000
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 74/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0059 - val_loss: 0.0051
# Epoch 75/1000
# 18/18 [==============================] - 2s 94ms/step - loss: 0.0061 - val_loss: 0.0117
# Epoch 76/1000
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 77/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0059 - val_loss: 0.0045
# Epoch 78/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0059 - val_loss: 0.0101
# Epoch 79/1000
# 18/18 [==============================] - 2s 93ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 80/1000
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 81/1000
# 18/18 [==============================] - 2s 89ms/step - loss: 0.0062 - val_loss: 0.0070
# Epoch 82/1000
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0056 - val_loss: 0.0045
# Epoch 83/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0054 - val_loss: 0.0057
# Epoch 84/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0058 - val_loss: 0.0068
# Epoch 85/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 86/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0061 - val_loss: 0.0042
# Epoch 87/1000
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0062 - val_loss: 0.0065
# Epoch 88/1000
# 18/18 [==============================] - 2s 88ms/step - loss: 0.0059 - val_loss: 0.0041
# Epoch 89/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0057 - val_loss: 0.0078
# Epoch 90/1000
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0053 - val_loss: 0.0138
# Epoch 91/1000
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0058 - val_loss: 0.0084
# Epoch 92/1000
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0066 - val_loss: 0.0036
# Epoch 93/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0069 - val_loss: 0.0054
# Epoch 94/1000
# 18/18 [==============================] - 2s 91ms/step - loss: 0.0059 - val_loss: 0.0069
# Epoch 95/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0065 - val_loss: 0.0106
# Epoch 96/1000
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0065 - val_loss: 0.0116
# Epoch 97/1000
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0054 - val_loss: 0.0077
# Epoch 98/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0054 - val_loss: 0.0065
# Epoch 99/1000
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0052 - val_loss: 0.0062
# Epoch 100/1000
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0051 - val_loss: 0.0066
# Epoch 101/1000
# 18/18 [==============================] - 2s 89ms/step - loss: 0.0048 - val_loss: 0.0079
# Epoch 102/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0056 - val_loss: 0.0057
# Epoch 103/1000
# 18/18 [==============================] - 2s 133ms/step - loss: 0.0052 - val_loss: 0.0070
# Epoch 104/1000
# 18/18 [==============================] - 2s 111ms/step - loss: 0.0052 - val_loss: 0.0067
# Epoch 105/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0052 - val_loss: 0.0114
# Epoch 106/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0052 - val_loss: 0.0133
# Epoch 107/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0055 - val_loss: 0.0106
# Epoch 108/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0051 - val_loss: 0.0097
# Epoch 109/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 110/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 111/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0060 - val_loss: 0.0040
# Epoch 112/1000
# 18/18 [==============================] - 2s 91ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 113/1000
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 114/1000
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0051 - val_loss: 0.0071
# Epoch 115/1000
# 18/18 [==============================] - 2s 89ms/step - loss: 0.0053 - val_loss: 0.0077
# Epoch 116/1000
# 18/18 [==============================] - 2s 88ms/step - loss: 0.0050 - val_loss: 0.0119
# Epoch 117/1000
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0049 - val_loss: 0.0080
# Epoch 118/1000
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0054 - val_loss: 0.0093
# Epoch 119/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0052 - val_loss: 0.0081
# Epoch 120/1000
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0046 - val_loss: 0.0062
# Epoch 121/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0048 - val_loss: 0.0102
# Epoch 122/1000
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0047 - val_loss: 0.0103
# Epoch 123/1000
# 18/18 [==============================] - 2s 92ms/step - loss: 0.0048 - val_loss: 0.0090
# Epoch 124/1000
# 18/18 [==============================] - 2s 94ms/step - loss: 0.0045 - val_loss: 0.0058
# Epoch 125/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0044 - val_loss: 0.0088
# Epoch 126/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0045 - val_loss: 0.0126
# Epoch 127/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0058 - val_loss: 0.0082
# Epoch 128/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0058 - val_loss: 0.0075
# Epoch 129/1000
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0049 - val_loss: 0.0163
# Epoch 130/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0045 - val_loss: 0.0085
# Epoch 131/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0053 - val_loss: 0.0153
# Epoch 132/1000
# 18/18 [==============================] - 2s 92ms/step - loss: 0.0052 - val_loss: 0.0070
# Epoch 133/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0045 - val_loss: 0.0111
# Epoch 134/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0043 - val_loss: 0.0078
# Epoch 135/1000
# 18/18 [==============================] - 2s 86ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 136/1000
# 18/18 [==============================] - 2s 93ms/step - loss: 0.0053 - val_loss: 0.0104
# Epoch 137/1000
# 18/18 [==============================] - 2s 92ms/step - loss: 0.0048 - val_loss: 0.0085
# Epoch 138/1000
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0044 - val_loss: 0.0061
# Epoch 139/1000
# 18/18 [==============================] - 2s 90ms/step - loss: 0.0040 - val_loss: 0.0069
# Epoch 140/1000
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0040 - val_loss: 0.0120
# Epoch 141/1000
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0042 - val_loss: 0.0112
# Epoch 142/1000
# 18/18 [==============================] - 2s 94ms/step - loss: 0.0040 - val_loss: 0.0108
# 2/2 [==============================] - 1s 25ms/step - loss: 1.8041e-16
#         MAE      MSE  MAPE
# Train 16.48   506.69  1.97
# Test  31.92 1,397.38  4.13
# 100%|██████████| 4/4 [30:08<00:00, 452.05s/it]

# %%
# if simul_test == 1:
# Performance plot by sequence length - 시퀀스/배치 변경에 따른 MSE 기록 -> 최적화 찾기 
seq_test = pd.DataFrame()
for key, val in Score.items():
    seq_test = pd.concat([seq_test, val.iloc[1,:].T], axis=1)

seq_test = seq_test.T
seq_test.index = start_list
seq_test['MSE'].plot(figsize=(12,4))
plt.show()
