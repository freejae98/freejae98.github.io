# %% [markdown]
# <a href="https://colab.research.google.com/github/freejae98/freejae98.github.io/blob/master/2022_06_29_New_Steel_v1_4_%EA%B8%B0%EA%B0%84%EB%B3%84_4%EA%B0%9C%EB%AA%A8%EB%8D%B8_%EC%A0%80%EC%9E%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ignore the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# System related and data input controls
import os

# Data manipulation, visualization and useful functions
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
pd.options.display.max_rows = 50
pd.options.display.max_columns = 40
import numpy as np
from itertools import product # iterative combinations
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

# Modeling algorithms
# General(Statistics/Econometrics)
from sklearn import preprocessing
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats

# Regression
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.kernel_ridge import KernelRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor, GradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# Classification
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# Model selection
from sklearn.model_selection import train_test_split,cross_validate
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

# Evaluation metrics
# for regression
from sklearn.metrics import mean_squared_log_error, mean_squared_error,  r2_score, mean_absolute_error
# for classification
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
### Evaluation of 1 pair of set
def evaluation(Y_real, Y_pred, graph_on=False):
    loss_length = len(Y_real.values.flatten()) - len(Y_pred)
    if loss_length != 0:
        Y_real = Y_real[loss_length:]
    if graph_on == True:
        pd.concat([Y_real, pd.DataFrame(Y_pred, index=Y_real.index, columns=['prediction'])], axis=1).plot(kind='line', figsize=(20,6),
                                                                                                           xlim=(Y_real.index.min(),Y_real.index.max()),
                                                                                                           linewidth=3, fontsize=20)
        plt.title('Time Series of Target', fontsize=20)
        plt.xlabel('Index', fontsize=15)
        plt.ylabel('Target Value', fontsize=15)
    MAE = abs(Y_real.values.flatten() - Y_pred).mean()
    MSE = ((Y_real.values.flatten() - Y_pred)**2).mean()
    MAPE = (abs(Y_real.values.flatten() - Y_pred)/Y_real.values.flatten()*100).mean()
    Score = pd.DataFrame([MAE, MSE, MAPE], index=['MAE', 'MSE', 'MAPE'], columns=['Score']).T
    Residual = pd.DataFrame(Y_real.values.flatten() - Y_pred, index=Y_real.index, columns=['Error'])
    return Score, Residual
# Score_tr, Residual_tr = evaluation(Y_train, pred_tr_reg1, graph_on=True)


### Evaluation of train/test pairs
def evaluation_trte(Y_real_tr, Y_pred_tr, Y_real_te, Y_pred_te, graph_on=False):
    Score_tr, Residual_tr = evaluation(Y_real_tr, Y_pred_tr, graph_on=graph_on)
    Score_te, Residual_te = evaluation(Y_real_te, Y_pred_te, graph_on=graph_on)
    Score_trte = pd.concat([Score_tr, Score_te], axis=0)
    Score_trte.index = ['Train', 'Test']
    return Score_trte, Residual_tr, Residual_te
# Score_reg1, Resid_tr_reg1, Resid_te_reg1 = evaluation_trte(Y_train, pred_tr_reg1, Y_test, pred_te_reg1, graph_on=True)

# %%
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, Activation, Flatten, Dropout
from keras.layers import SimpleRNN, LSTM, GRU

from pickle import dump

# %%
# Data Loading
df = pd.read_excel('/content/data_completed.xlsx')   #dataset_6 사용
df.set_index('Date', inplace=True)

X_colname = ['MA5']
raw_all = df[X_colname]

# raw_all = df.loc[df['MA5'] != np.nan, :]

#20%는 테스트용 구분함
# PCT = 0.2
# c_num = int(len(raw_all.index) * (1- PCT))

# criteria = raw_all.index[int(c_num)]


# raw_all = df.loc[df.index >= '2019-12-30', X_colname]

# Parameters - 시작점을 달리할 경우 정확도에 어떤 영향을 얻을 수 있는지?

start_point = '2017-1-1'     #기존 시작점 : '2019-12-30'
# start_list = ['2016-1-1', '2018-1-1', '2020-1-1', '2021-1-1']     #기존 시작점 : '2019-12-30'
criteria = '2022-04-01'     #기존 시작점 : '2021-09-01'

scaler = preprocessing.MinMaxScaler()
sequence = 15   # → optimization 진행
batch_size = 16
epoch = 300
verbose = 1  # 원래는 1
dropout_ratio = 0

#며칠이나 이후 것을 예상할 것인지 (20 = 4주 후)
predict_day = 5    #5*1 # 1주 후

predict_day_list = [5, 10, 15, 20]    #각 1,2,3,4주 후



# Feature Engineering
## Train & Test Split
# train = raw_all.loc[raw_all.index < criteria,:]

# %%
#################################################################################
#
# ----- Feature 1, GRU 버전 -------
#
#################################################################################

from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor = 'val_loss', min_delta = 0, patience = 50, mode = 'min')


####################### iterations #######################
Score = dict()

temp = 0

# batchsize_list = [i for i in range(5, 11, 5)]
for i in tqdm(predict_day_list):
    # sequence = i
    # start_point = i

    predict_day = i   #예측일 변경

    temp = temp + 1


    train = raw_all.loc[(raw_all.index >= start_point) & (raw_all.index < criteria)]

    test = raw_all.loc[raw_all.index >= criteria,:]
    print('Train_size:', train.shape, 'Test_size:', test.shape)

    print('Train_start:', train.index[0])
    print('Test_start:', test.index[0])

    # Scaling
    train_scaled = scaler.fit_transform(train)
    test_scaled = scaler.transform(test)



    ## X / Y Split
    X_train, Y_train = [], []
    for index in range(0, len(train_scaled) - sequence - predict_day):
        X_train.append(train_scaled[index: index + sequence])
        Y_train.append(train_scaled[index + sequence + predict_day])
    X_test, Y_test = [], []
    for index in range(0, len(test_scaled) - sequence - predict_day):
        X_test.append(test_scaled[index: index + sequence])
        Y_test.append(test_scaled[index + sequence + predict_day])

    ## Retype and Reshape
    X_train, Y_train = np.array(X_train), np.array(Y_train)
    X_test, Y_test = np.array(X_test), np.array(Y_test)
    print('X_train:', X_train.shape, 'Y_train:', Y_train.shape)
    print('X_test:', X_test.shape, 'Y_test:', Y_test.shape)

    # GRU
    model = Sequential()
    model.add(GRU(128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True, activation='relu'))
    model.add(Dropout(dropout_ratio)) 
    model.add(GRU(256, return_sequences=True, activation="relu"))
    model.add(Dropout(dropout_ratio)) 
    model.add(GRU(128, return_sequences=True, activation="relu"))
    model.add(Dropout(dropout_ratio)) 
    model.add(GRU(64, return_sequences=False, activation="relu"))
    model.add(Dropout(dropout_ratio)) 
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    # model.summary()
    model_fit = model.fit(X_train, Y_train, 
                          batch_size=batch_size, epochs=epoch,
                          verbose=verbose, validation_data=(X_test, Y_test), callbacks = [early_stopping])

    plt.plot(pd.DataFrame(model_fit.history))
    plt.grid(True)
    plt.show()

    # prediction
    Y_train_pred = model.predict(X_train)
    Y_test_pred = model.predict(X_test)

    # evaluation
    result = model.evaluate(X_test, Y_test_pred)
    if scaler != []:
        Y_train = scaler.inverse_transform(Y_train)
        Y_train_pred = scaler.inverse_transform(Y_train_pred)
        Y_test = scaler.inverse_transform(Y_test)
        Y_test_pred = scaler.inverse_transform(Y_test_pred)
    Score_GRU, Residual_tr, Residual_te = evaluation_trte(pd.DataFrame(Y_train), Y_train_pred.flatten(), 
                                                          pd.DataFrame(Y_test), Y_test_pred.flatten(), graph_on=True)
    display(Score_GRU)
# if simul_test == 1:
    Score[str(predict_day)] = Score_GRU



    #모델, scaler 저장하기
    model.save("steel_" + str(temp) + "d.h5")

    dump(scaler, open("scaler_" + str(temp) + "d.pkl", 'wb'))



# error analysis
# error_analysis(Residual_te, ['Error'], pd.DataFrame(X_train.reshape(X_train.shape[0], X_train.shape[1])), graph_on=True)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Train_size: (1369, 1) Test_size: (45, 1)
# Train_start: 2017-01-02 00:00:00
# Test_start: 2022-04-01 00:00:00
# X_train: (1349, 15, 1) Y_train: (1349, 1)
# X_test: (25, 15, 1) Y_test: (25, 1)
# Epoch 1/300
# 85/85 [==============================] - 13s 85ms/step - loss: 0.0163 - val_loss: 0.0032
# Epoch 2/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0020 - val_loss: 0.0092
# Epoch 3/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0020 - val_loss: 0.0035
# Epoch 4/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0021 - val_loss: 0.0010
# Epoch 5/300
# 85/85 [==============================] - 7s 78ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 6/300
# 85/85 [==============================] - 7s 78ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 7/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0017 - val_loss: 0.0176
# Epoch 8/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 9/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 10/300
# 85/85 [==============================] - 6s 76ms/step - loss: 0.0014 - val_loss: 0.0065
# Epoch 11/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0013 - val_loss: 0.0069
# Epoch 12/300
# 85/85 [==============================] - 7s 79ms/step - loss: 0.0014 - val_loss: 0.0028
# Epoch 13/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0015 - val_loss: 9.6304e-04
# Epoch 14/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 15/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 16/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0014 - val_loss: 8.8803e-04
# Epoch 17/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 18/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 19/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 20/300
# 85/85 [==============================] - 7s 78ms/step - loss: 0.0011 - val_loss: 0.0026
# Epoch 21/300
# 85/85 [==============================] - 7s 78ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 22/300
# 85/85 [==============================] - 7s 77ms/step - loss: 0.0012 - val_loss: 0.0043
# Epoch 23/300
# 85/85 [==============================] - 7s 78ms/step - loss: 0.0011 - val_loss: 7.2645e-04
# Epoch 24/300
# 85/85 [==============================] - 7s 79ms/step - loss: 0.0011 - val_loss: 5.4872e-04
# Epoch 25/300
# 85/85 [==============================] - 7s 78ms/step - loss: 9.8610e-04 - val_loss: 9.3880e-04
# Epoch 26/300
# 85/85 [==============================] - 7s 80ms/step - loss: 9.9340e-04 - val_loss: 0.0041
# Epoch 27/300
# 85/85 [==============================] - 7s 78ms/step - loss: 9.3317e-04 - val_loss: 0.0032
# Epoch 28/300
# 85/85 [==============================] - 7s 78ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 29/300
# 85/85 [==============================] - 7s 78ms/step - loss: 8
 1)
# Train_start: 2017-01-02 00:00:00
# Test_start: 2022-04-01 00:00:00
# X_train: (1344, 15, 1) Y_train: (1344, 1)
# X_test: (20, 15, 1) Y_test: (20, 1)
# Epoch 1/300
# 84/84 [==============================] - 11s 87ms/step - loss: 0.0172 - val_loss: 0.0041
# Epoch 2/300
# 84/84 [==============================] - 7s 78ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 3/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 4/300
# 84/84 [==============================] - 7s 84ms/step - loss: 0.0037 - val_loss: 0.0155
# Epoch 5/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0031 - val_loss: 0.0057
# Epoch 6/300
# 84/84 [==============================] - 7s 78ms/step - loss: 0.0026 - val_loss: 0.0150
# Epoch 7/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0029 - val_loss: 0.0046
# Epoch 8/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0024 - val_loss: 0.0077
# Epoch 9/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0024 - val_loss: 0.0049
# Epoch 10/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0027 - val_loss: 0.0038
# Epoch 11/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0023 - val_loss: 0.0080
# Epoch 12/300
# 84/84 [==============================] - 7s 79ms/step - loss: 0.0023 - val_loss: 0.0087
# Epoch 13/300
# 84/84 [==============================] - 7s 80ms/step - loss: 0.0023 - val_loss: 0.0078
# Epoch 14/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 15/300
# 84/84 [==============================] - 6s 75ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 16/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 17/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0022 - val_loss: 0.0121
# Epoch 18/300
# 84/84 [==============================] - 6s 76ms/step - loss: 0.0022 - val_loss: 0.0041
# Epoch 19/300
# 84/84 [==============================] - 8s 94ms/step - loss: 0.0023 - val_loss: 0.0093
# Epoch 20/300
# 84/84 [==============================] - 7s 78ms/step - loss: 0.0023 - val_loss: 0.0109
# Epoch 21/300
# 84/84 [==============================] - 7s 84ms/step - loss: 0.0021 - val_loss: 0.0088
# Epoch 22/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0020 - val_loss: 0.0046
# Epoch 23/300
# 84/84 [==============================] - 7s 78ms/step - loss: 0.0021 - val_loss: 0.0051
# Epoch 24/300
# 84/84 [==============================] - 7s 79ms/step - loss: 0.0022 - val_loss: 0.0161
# Epoch 25/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0022 - val_loss: 0.0057
# Epoch 26/300
# 84/84 [==============================] - 7s 80ms/step - loss: 0.0019 - val_loss: 0.0052
# Epoch 27/300
# 84/84 [==============================] - 6s 76ms/step - loss: 0.0020 - val_loss: 0.0103
# Epoch 28/300
# 84/84 [==============================] - 7s 85ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 29/300
# 84/84 [==============================] - 7s 80ms/step - loss: 0.0020 - val_loss: 0.0070
# Epoch 30/300
# 84/84 [==============================] - 6s 74ms/step - loss: 0.0020 - val_loss: 0.0052
# Epoch 31/300
# 84/84 [==============================] - 6s 76ms/step - loss: 0.0020 - val_loss: 0.0045
# Epoch 32/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0019 - val_loss: 0.0126
# Epoch 33/300
# 84/84 [==============================] - 7s 83ms/step - loss: 0.0018 - val_loss: 0.0092
# Epoch 34/300
# 84/84 [==============================] - 7s 80ms/step - loss: 0.0019 - val_loss: 0.0103
# Epoch 35/300
# 84/84 [==============================] - 7s 82ms/step - loss: 0.0018 - val_loss: 0.0087
# Epoch 36/300
# 84/84 [==============================] - 7s 84ms/step - loss: 0.0020 - val_loss: 0.0082
# Epoch 37/300
# 84/84 [==============================] - 6s 77ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 38/300
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0019 - val_loss: 0.0056
# Epoch 39/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 40/300
# 84/84 [==============================] - 6s 75ms/step - loss: 0.0019 - val_loss: 0.0108
# Epoch 41/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0018 - val_loss: 0.0071
# Epoch 42/300
# 84/84 [==============================] - 6s 76ms/step - loss: 0.0018 - val_loss: 0.0137
# Epoch 43/300
# 84/84 [==============================] - 6s 76ms/step - loss: 0.0020 - val_loss: 0.0070
# Epoch 44/300
# 84/84 [==============================] - 7s 87ms/step - loss: 0.0017 - val_loss: 0.0105
# Epoch 45/300
# 84/84 [==============================] - 6s 77ms/step - loss: 0.0017 - val_loss: 0.0060
# Epoch 46/300
# 84/84 [==============================] - 7s 81ms/step - loss: 0.0019 - val_loss: 0.0138
# Epoch 47/300
# 84/84 [==============================] - 7s 85ms/step - loss: 0.0018 - val_loss: 0.0064
# Epoch 48/300
# 84/84 [==============================] - 7s 86ms/step - loss: 0.0017 - val_loss: 0.0108
# Epoch 49/300
# 84/84 [==============================] - 8s 93ms/step - loss: 0.0018 - val_loss: 0.0043
# Epoch 50/300
# 84/84 [==============================] - 6s 76ms/step - loss: 0.0017 - val_loss: 0.0075
# Epoch 51/300
# 84/84 [==============================] - 7s 89ms/step - loss: 0.0018 - val_loss: 0.0085
# Epoch 52/300
# 84/84 [==============================] - 8s 92ms/step - loss: 0.0017 - val_loss: 0.0066
# Epoch 53/300
# 84/84 [==============================] - 7s 87ms/step - loss: 0.0017 - val_loss: 0.0062
# 1/1 [==============================] - 0s 42ms/step - loss: 7.1054e-16
#         MAE      MSE  MAPE
# Train 15.74   523.58  2.45
# Test  44.90 2,193.35  6.04
#  50%|█████     | 2/4 [17:47<16:56, 508.05s/it]
# Train_size: (1369, 1) Test_size: (45, 1)
# Train_start: 2017-01-02 00:00:00
# Test_start: 2022
300
# 84/84 [==============================] - 8s 93ms/step - loss: 0.0026 - val_loss: 0.0242
# Epoch 38/300
# 84/84 [==============================] - 8s 90ms/step - loss: 0.0025 - val_loss: 0.0163
# Epoch 39/300
# 84/84 [==============================] - 8s 95ms/step - loss: 0.0027 - val_loss: 0.0116
# Epoch 40/300
# 84/84 [==============================] - 9s 107ms/step - loss: 0.0025 - val_loss: 0.0237
# Epoch 41/300
# 84/84 [==============================] - 8s 91ms/step - loss: 0.0026 - val_loss: 0.0208
# Epoch 42/300
# 84/84 [==============================] - 8s 90ms/step - loss: 0.0026 - val_loss: 0.0246
# Epoch 43/300
# 84/84 [==============================] - 8s 99ms/step - loss: 0.0026 - val_loss: 0.0179
# Epoch 44/300
# 84/84 [==============================] - 8s 93ms/step - loss: 0.0025 - val_loss: 0.0169
# Epoch 45/300
# 84/84 [==============================] - 8s 94ms/step - loss: 0.0026 - val_loss: 0.0106
# Epoch 46/300
# 84/84 [==============================] - 8s 95ms/step - loss: 0.0026 - val_loss: 0.0168
# Epoch 47/300
# 84/84 [==============================] - 8s 93ms/step - loss: 0.0025 - val_loss: 0.0119
# Epoch 48/300
# 84/84 [==============================] - 8s 96ms/step - loss: 0.0023 - val_loss: 0.0254
# Epoch 49/300
# 84/84 [==============================] - 8s 96ms/step - loss: 0.0025 - val_loss: 0.0282
# Epoch 50/300
# 84/84 [==============================] - 8s 94ms/step - loss: 0.0023 - val_loss: 0.0075
# Epoch 51/300
# 84/84 [==============================] - 8s 93ms/step - loss: 0.0024 - val_loss: 0.0149
# Epoch 52/300
# 84/84 [==============================] - 8s 97ms/step - loss: 0.0025 - val_loss: 0.0236
# Epoch 53/300
# 84/84 [==============================] - 8s 93ms/step - loss: 0.0024 - val_loss: 0.0183
# Epoch 54/300
# 84/84 [==============================] - 8s 92ms/step - loss: 0.0024 - val_loss: 0.0257
# Epoch 55/300
# 84/84 [==============================] - 8s 94ms/step - loss: 0.0024 - val_loss: 0.0251
# Epoch 56/300
# 84/84 [==============================] - 10s 114ms/step - loss: 0.0026 - val_loss: 0.0123
# Epoch 57/300
# 84/84 [==============================] - 9s 110ms/step - loss: 0.0025 - val_loss: 0.0148
# Epoch 58/300
# 84/84 [==============================] - 8s 94ms/step - loss: 0.0026 - val_loss: 0.0193
# 1/1 [==============================] - 0s 34ms/step - loss: 1.4211e-15
#         MAE      MSE  MAPE
# Train 22.37   909.36  3.53
# Test  80.88 6,799.61 11.05
#  75%|███████▌  | 3/4 [26:19<08:29, 509.99s/it]
# Train_size: (1369, 1) Test_size: (45, 1)
# Train_start: 2017-01-02 00:00:00
# Test_start: 2022-04-01 00:00:00
# X_train: (1334, 15, 1) Y_train: (1334, 1)
# X_test: (10, 15, 1) Y_test: (10, 1)
# Epoch 1/300
# 84/84 [==============================] - 15s 102ms/step - loss: 0.0200 - val_loss: 0.0537
# Epoch 2/300
# 84/84 [==============================] - 8s 89ms/step - loss: 0.0052 - val_loss: 0.0353
# Epoch 3/300
# 84/84 [==============================] - 8s 93ms/step - loss: 0.0051 - val_loss: 0.0471
# Epoch 4/300
# 84/84 [==============================] - 8s 96ms/step - loss: 0.0053 - val_loss: 0.0190
# Epoch 5/300
# 84/84 [==============================] - 7s 85ms/step - loss: 0.0051 - val_loss: 0.0231
# Epoch 6/300
# 84/84 [==============================] - 7s 88ms/step - loss: 0.0047 - val_loss: 0.0295
# Epoch 7/300
# 84/84 [==============================] - 8s 92ms/step - loss: 0.0060 - val_loss: 0.0296
# Epoch 8/300
# 84/84 [==============================] - 8s 92ms/step - loss: 0.0048 - val_loss: 0.0310
# Epoch 9/300
# 84/84 [==============================] - 8s 91ms/step - loss: 0.0043 - val_loss: 0.0212
# Epoch 10/300
# 84/84 [==============================] - 8s 93ms/step - loss: 0.0043 - val_loss: 0.0216
# Epoch 11/300
# 84/84 [==============================] - 8s 93ms/step - loss: 0.0043 - val_loss: 0.0139
# Epoch 12/300
# 84/84 [==============================] - 8s 93ms/step - loss: 0.0043 - val_loss: 0.0172
# Epoch 13/300
# 84/84 [==============================] - 8s 94ms/step - loss: 0.0041 - val_loss: 0.0210
# Epoch 14/300
# 84/84 [==============================] - 9s 106ms/step - loss: 0.0039 - val_loss: 0.0223
# Epoch 15/300
# 84/84 [==============================] - 8s 95ms/step - loss: 0.
# 84/84 [==============================] - 12s 141ms/step - loss: 0.0028 - val_loss: 0.0282
# Epoch 53/300
# 84/84 [==============================] - 12s 138ms/step - loss: 0.0030 - val_loss: 0.0358
# Epoch 54/300
# 84/84 [==============================] - 10s 116ms/step - loss: 0.0028 - val_loss: 0.0296
# Epoch 55/300
# 84/84 [==============================] - 11s 131ms/step - loss: 0.0028 - val_loss: 0.0295
# Epoch 56/300
# 84/84 [==============================] - 11s 126ms/step - loss: 0.0030 - val_loss: 0.0213
# Epoch 57/300
# 84/84 [==============================] - 11s 130ms/step - loss: 0.0028 - val_loss: 0.0181
# Epoch 58/300
# 84/84 [==============================] - 10s 118ms/step - loss: 0.0029 - val_loss: 0.0351
# Epoch 59/300
# 84/84 [==============================] - 8s 97ms/step - loss: 0.0030 - val_loss: 0.0335
# Epoch 60/300
# 84/84 [==============================] - 8s 98ms/step - loss: 0.0028 - val_loss: 0.0311
# Epoch 61/300
# 84/84 [==============================] - 10s 122ms/step - loss: 0.0027 - val_loss: 0.0336
# Epoch 62/300
# 84/84 [==============================] - 9s 111ms/step - loss: 0.0029 - val_loss: 0.0483
# Epoch 63/300
# 84/84 [==============================] - 8s 95ms/step - loss: 0.0028 - val_loss: 0.0235
# Epoch 64/300
# 84/84 [==============================] - 8s 98ms/step - loss: 0.0028 - val_loss: 0.0320
# Epoch 65/300
# 84/84 [==============================] - 8s 91ms/step - loss: 0.0031 - val_loss: 0.0482
# Epoch 66/300
# 84/84 [==============================] - 7s 88ms/step - loss: 0.0027 - val_loss: 0.0223
# Epoch 67/300
# 84/84 [==============================] - 8s 89ms/step - loss: 0.0028 - val_loss: 0.0356
# Epoch 68/300
# 84/84 [==============================] - 8s 93ms/step - loss: 0.0026 - val_loss: 0.0497
# Epoch 69/300
# 84/84 [==============================] - 8s 96ms/step - loss: 0.0027 - val_loss: 0.0348
# Epoch 70/300
# 84/84 [==============================] - 7s 87ms/step - loss: 0.0026 - val_loss: 0.0243
# Epoch 71/300
# 84/84 [==============================] - 8s 91ms/step - loss: 0.0025 - val_loss: 0.0241
# Epoch 72/300
# 84/84 [==============================] - 8s 93ms/step - loss: 0.0025 - val_loss: 0.0397
# Epoch 73/300
# 84/84 [==============================] - 8s 93ms/step - loss: 0.0027 - val_loss: 0.0206
# Epoch 74/300
# 84/84 [==============================] - 8s 91ms/step - loss: 0.0026 - val_loss: 0.0197
# Epoch 75/300
# 84/84 [==============================] - 8s 90ms/step - loss: 0.0026 - val_loss: 0.0244
# Epoch 76/300
# 84/84 [==============================] - 8s 95ms/step - loss: 0.0025 - val_loss: 0.0290
# Epoch 77/300
# 84/84 [==============================] - 8s 89ms/step - loss: 0.0027 - val_loss: 0.0277
# Epoch 78/300
# 84/84 [==============================] - 7s 86ms/step - loss: 0.0026 - val_loss: 0.0345
# Epoch 79/300
# 84/84 [==============================] - 7s 87ms/step - loss: 0.0025 - val_loss: 0.0292
# Epoch 80/300
# 84/84 [==============================] - 7s 87ms/step - loss: 0.0024 - val_loss: 0.0236
# Epoch 81/300
# 84/84 [==============================] - 8s 91ms/step - loss: 0.0025 - val_loss: 0.0315
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0658e-15
#          MAE       MSE  MAPE
# Train  22.19    811.79  3.48
# Test  102.75 11,113.80 14.11
# 100%|██████████| 4/4 [38:51<00:00, 582.94s/it]

# %%
# if simul_test == 1:
# Performance plot by sequence length - 시퀀스/배치 변경에 따른 MSE 기록 -> 최적화 찾기 
seq_test = pd.DataFrame()
for key, val in Score.items():
    seq_test = pd.concat([seq_test, val.iloc[1,:].T], axis=1)

seq_test = seq_test.T
seq_test.index = predict_day_list
seq_test['MSE'].plot(figsize=(12,4))
plt.show()
